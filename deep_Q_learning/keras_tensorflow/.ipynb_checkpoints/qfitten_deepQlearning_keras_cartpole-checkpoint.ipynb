# %% [markdown]
# # Q-Learner for cartpole

# %% [markdown]
# - Q-Learning algo written in Keras for the cartpole
#
# - Batch version used here, Q function updated after each episode of simulation

# %%
# imports
import os 
import sys
sys.path.append('../../')

# import custom reinforcement library
import reinforcement_library as reinlib

# import cartpole + pytorch online q-learner
learner = reinlib.deep_Q_Learning.batch_cartpole_keras
plotter = reinlib.deep_Q_Learning.history_plotter

# load in autoreload so any changes made to backend files mirrored in notebook
# without the need to restart kernel
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# - Q-Learner Algo can be loaded in from backend file by activating the command
#
# ```learner.QLearner??```
#
# in a code cell

# %% [markdown]
# ## Q Learning setup interface

# %%
# feed in current directory name and savename = experiment name
dirname = os.getcwd()
savename = 'batch_cartpole_experiment_1'

# initialize Q Learn process
num_episodes = 300
explore_decay = 1
explore_val = 0.01
exit_level = 200
exit_window = 50

# initialize memory
episode_update = 1
memory_length = 2

# load into instance of learner
demo = learner.QLearner(dirname,savename,num_episodes=num_episodes,explore_decay=explore_decay,explore_val=explore_val,memory_length=memory_length,episode_update=episode_update,exit_level=exit_level,exit_window=exit_window)

# initialize Q function
layer_sizes = [200,200]
alpha = 10**(-2)
activation = 'relu'
demo.initialize_Q(layer_sizes=layer_sizes,alpha=alpha,activation=activation)
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
demo.train()
# Out:
# episode 1 of 300 complete,  explore val = 0.01, episode reward = -196.4, ave reward = 0.0
# episode 2 of 300 complete,  explore val = 0.01, episode reward = -581.3, ave reward = -3.9
# episode 3 of 300 complete,  explore val = 0.01, episode reward = -478.6, ave reward = -15.6
# episode 4 of 300 complete,  explore val = 0.01, episode reward = -621.1, ave reward = -25.1
# episode 5 of 300 complete,  explore val = 0.01, episode reward = -206.0, ave reward = -37.5
# episode 6 of 300 complete,  explore val = 0.01, episode reward = -132.2, ave reward = -41.7
# episode 7 of 300 complete,  explore val = 0.01, episode reward = -434.1, ave reward = -44.3
# episode 8 of 300 complete,  explore val = 0.01, episode reward = -187.9, ave reward = -53.0
# episode 9 of 300 complete,  explore val = 0.01, episode reward = -352.3, ave reward = -56.7
# episode 10 of 300 complete,  explore val = 0.01, episode reward = -296.5, ave reward = -63.8
# episode 11 of 300 complete,  explore val = 0.01, episode reward = -606.0, ave reward = -69.7
# episode 12 of 300 complete,  explore val = 0.01, episode reward = -202.9, ave reward = -81.8
# episode 13 of 300 complete,  explore val = 0.01, episode reward = -763.4, ave reward = -85.9
# episode 14 of 300 complete,  explore val = 0.01, episode reward = -149.7, ave reward = -101.2
# episode 15 of 300 complete,  explore val = 0.01, episode reward = -171.3, ave reward = -104.2
# episode 16 of 300 complete,  explore val = 0.01, episode reward = -173.3, ave reward = -107.6
# episode 17 of 300 complete,  explore val = 0.01, episode reward = 161.3, ave reward = -111.1
# episode 18 of 300 complete,  explore val = 0.01, episode reward = -355.8, ave reward = -107.8
# episode 19 of 300 complete,  explore val = 0.01, episode reward = -240.2, ave reward = -114.9
# episode 20 of 300 complete,  explore val = 0.01, episode reward = -123.1, ave reward = -119.8
# episode 21 of 300 complete,  explore val = 0.01, episode reward = -206.9, ave reward = -122.2
# episode 22 of 300 complete,  explore val = 0.01, episode reward = -54.7, ave reward = -126.4
# episode 23 of 300 complete,  explore val = 0.01, episode reward = -706.2, ave reward = -127.4
# episode 24 of 300 complete,  explore val = 0.01, episode reward = -144.5, ave reward = -141.6
# episode 25 of 300 complete,  explore val = 0.01, episode reward = -372.8, ave reward = -144.5
# episode 26 of 300 complete,  explore val = 0.01, episode reward = -42.1, ave reward = -151.9
# episode 27 of 300 complete,  explore val = 0.01, episode reward = -195.6, ave reward = -152.8
# episode 28 of 300 complete,  explore val = 0.01, episode reward = -195.1, ave reward = -156.7
# episode 29 of 300 complete,  explore val = 0.01, episode reward = -65.8, ave reward = -160.6
# episode 30 of 300 complete,  explore val = 0.01, episode reward = 24.6, ave reward = -161.9
# episode 31 of 300 complete,  explore val = 0.01, episode reward = -91.0, ave reward = -161.4
# episode 32 of 300 complete,  explore val = 0.01, episode reward = -44.1, ave reward = -163.2
# episode 33 of 300 complete,  explore val = 0.01, episode reward = 31.2, ave reward = -164.1
# episode 34 of 300 complete,  explore val = 0.01, episode reward = 31.4, ave reward = -163.5
# episode 35 of 300 complete,  explore val = 0.01, episode reward = -109.7, ave reward = -162.8
# episode 36 of 300 complete,  explore val = 0.01, episode reward = -61.3, ave reward = -165.0
# episode 37 of 300 complete,  explore val = 0.01, episode reward = -17.4, ave reward = -166.3
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-50-3199fc223f58> in <module>()
# ----> 1 demo.train()
#
# /home/jovyan/work/reinforcement_library/deep_Q_Learning/batch_cartpole_keras.py in train(self, **kwargs)
#     239             while done == False and step < 500:
#     240                 # choose next action
# --> 241                 action = self.choose_action(state)
#     242
#     243                 # transition to next state, get associated reward
#
# /home/jovyan/work/reinforcement_library/deep_Q_Learning/batch_cartpole_keras.py in choose_action(self, state)
#     214
#     215         # pick action based on exploiting
# --> 216         qs = self.Q(state)
#     217         if p > self.explore_val:
#     218             action = np.argmax(qs)
#
# /opt/conda/lib/python3.5/site-packages/keras/models.py in predict(self, x, batch_size, verbose)
#     897         if self.model is None:
#     898             self.build()
# --> 899         return self.model.predict(x, batch_size=batch_size, verbose=verbose)
#     900
#     901     def predict_on_batch(self, x):
#
# /opt/conda/lib/python3.5/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose)
#    1571         f = self.predict_function
#    1572         return self._predict_loop(f, ins,
# -> 1573                                   batch_size=batch_size, verbose=verbose)
#    1574
#    1575     def train_on_batch(self, x, y,
#
# /opt/conda/lib/python3.5/site-packages/keras/engine/training.py in _predict_loop(self, f, ins, batch_size, verbose)
#    1201                 ins_batch = _slice_arrays(ins, batch_ids)
#    1202
# -> 1203             batch_outs = f(ins_batch)
#    1204             if not isinstance(batch_outs, list):
#    1205                 batch_outs = [batch_outs]
#
# /opt/conda/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2101         session = get_session()
#    2102         updated = session.run(self.outputs + [self.updates_op],
# -> 2103                               feed_dict=feed_dict)
#    2104         return updated[:len(self.outputs)]
#    2105
#
# /opt/conda/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     776     try:
#     777       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 778                          run_metadata_ptr)
#     779       if run_metadata:
#     780         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /opt/conda/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     980     if final_fetches or final_targets:
#     981       results = self._do_run(handle, final_targets, final_fetches,
# --> 982                              feed_dict_string, options, run_metadata)
#     983     else:
#     984       results = []
#
# /opt/conda/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1030     if handle is None:
#    1031       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1032                            target_list, options, run_metadata)
#    1033     else:
#    1034       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /opt/conda/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1037   def _do_call(self, fn, *args):
#    1038     try:
# -> 1039       return fn(*args)
#    1040     except errors.OpError as e:
#    1041       message = compat.as_text(e.message)
#
# /opt/conda/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1019         return tf_session.TF_Run(session, options,
#    1020                                  feed_dict, fetch_list, target_list,
# -> 1021                                  status, run_metadata)
#    1022
#    1023     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# # plot total episode reward history

# %%
reward_logname = 'reward_logs/' + savename + '.txt'
plotter.plot_reward_history(reward_logname,window_length = exit_window)
