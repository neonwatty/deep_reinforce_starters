# %% [markdown]
# # Q-Learner for cartpole

# %% [markdown]
# - Q-Learning algo written in Keras for the cartpole
#
# - Batch version used here, Q function updated after each episode of simulation

# %%
# imports
import os 
import sys
sys.path.append('../../')

# import custom reinforcement library
import reinforcement_library as reinlib

# import cartpole + pytorch online q-learner
learner = reinlib.deep_Q_Learning.batch_cartpole_keras
plotter = reinlib.deep_Q_Learning.history_plotter

# load in autoreload so any changes made to backend files mirrored in notebook
# without the need to restart kernel
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# - Q-Learner Algo can be loaded in from backend file by activating the command
#
# ```learner.QLearner??```
#
# in a code cell

# %% [markdown]
# ## Q Learning setup interface

# %%
# feed in current directory name and savename = experiment name
dirname = os.getcwd()
savename = 'batch_cartpole_experiment_1'

# initialize Q Learn process
num_episodes = 300
explore_decay = 1
explore_val = 0.01
exit_level = 200
exit_window = 100

# initialize memory
episode_update = 1
memory_length = 2

# load into instance of learner
demo = learner.QLearner(dirname,savename,num_episodes=num_episodes,explore_decay=explore_decay,explore_val=explore_val,memory_length=memory_length,episode_update=episode_update,exit_level=exit_level,exit_window=exit_window)

# initialize Q function
layer_sizes = [200,200]
alpha = 10**(-2)
activation = 'relu'
demo.initialize_Q(layer_sizes=layer_sizes,alpha=alpha,activation=activation)
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
demo.train()
# Out:
# episode 1 of 300 complete,  explore val = 0.01, episode reward = 10.0, ave reward = 0.0
# episode 2 of 300 complete,  explore val = 0.01, episode reward = 25.0, ave reward = 0.1
# episode 3 of 300 complete,  explore val = 0.01, episode reward = 11.0, ave reward = 0.4
# episode 4 of 300 complete,  explore val = 0.01, episode reward = 13.0, ave reward = 0.5
# episode 5 of 300 complete,  explore val = 0.01, episode reward = 33.0, ave reward = 0.6
# episode 6 of 300 complete,  explore val = 0.01, episode reward = 88.0, ave reward = 0.9
# episode 7 of 300 complete,  explore val = 0.01, episode reward = 50.0, ave reward = 1.8
# episode 8 of 300 complete,  explore val = 0.01, episode reward = 45.0, ave reward = 2.3
# episode 9 of 300 complete,  explore val = 0.01, episode reward = 36.0, ave reward = 2.8
# episode 10 of 300 complete,  explore val = 0.01, episode reward = 43.0, ave reward = 3.1
# episode 11 of 300 complete,  explore val = 0.01, episode reward = 78.0, ave reward = 3.5
# episode 12 of 300 complete,  explore val = 0.01, episode reward = 41.0, ave reward = 4.3
# episode 13 of 300 complete,  explore val = 0.01, episode reward = 44.0, ave reward = 4.7
# episode 14 of 300 complete,  explore val = 0.01, episode reward = 49.0, ave reward = 5.2
# episode 15 of 300 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 5.7
# episode 16 of 300 complete,  explore val = 0.01, episode reward = 102.0, ave reward = 10.7
# episode 17 of 300 complete,  explore val = 0.01, episode reward = 70.0, ave reward = 11.7
# episode 18 of 300 complete,  explore val = 0.01, episode reward = 104.0, ave reward = 12.4
# episode 19 of 300 complete,  explore val = 0.01, episode reward = 29.0, ave reward = 13.4
# episode 20 of 300 complete,  explore val = 0.01, episode reward = 79.0, ave reward = 13.7
# episode 21 of 300 complete,  explore val = 0.01, episode reward = 55.0, ave reward = 14.5
# episode 22 of 300 complete,  explore val = 0.01, episode reward = 31.0, ave reward = 15.0
# episode 23 of 300 complete,  explore val = 0.01, episode reward = 49.0, ave reward = 15.4
# episode 24 of 300 complete,  explore val = 0.01, episode reward = 124.0, ave reward = 15.8
# episode 25 of 300 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 17.1
# episode 26 of 300 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 22.1
# episode 27 of 300 complete,  explore val = 0.01, episode reward = 156.0, ave reward = 27.1
# episode 28 of 300 complete,  explore val = 0.01, episode reward = 166.0, ave reward = 28.6
# episode 29 of 300 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 30.3
# episode 30 of 300 complete,  explore val = 0.01, episode reward = 100.0, ave reward = 35.3
# episode 31 of 300 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 36.3
# episode 32 of 300 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 41.3
# episode 33 of 300 complete,  explore val = 0.01, episode reward = 263.0, ave reward = 46.3
# episode 34 of 300 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 48.9
# episode 35 of 300 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 53.9
# episode 36 of 300 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 58.9
# episode 37 of 300 complete,  explore val = 0.01, episode reward = 146.0, ave reward = 63.9
# episode 38 of 300 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 65.4
# episode 39 of 300 complete,  explore val = 0.01, episode reward = 98.0, ave reward = 70.4
# episode 40 of 300 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 71.4
# episode 41 of 300 complete,  explore val = 0.01, episode reward = 164.0, ave reward = 76.4
# episode 42 of 300 complete,  explore val = 0.01, episode reward = 45.0, ave reward = 78.0
# episode 43 of 300 complete,  explore val = 0.01, episode reward = 60.0, ave reward = 78.5
# episode 44 of 300 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 79.1
# episode 45 of 300 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 84.1
# episode 46 of 300 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 89.1
# episode 47 of 300 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 94.1
# episode 48 of 300 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 99.1
# episode 49 of 300 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 104.1
# episode 50 of 300 complete,  explore val = 0.01, episode reward = 264.0, ave reward = 109.1
# episode 51 of 300 complete,  explore val = 0.01, episode reward = 142.0, ave reward = 111.7
# episode 52 of 300 complete,  explore val = 0.01, episode reward = 87.0, ave reward = 113.1
# episode 53 of 300 complete,  explore val = 0.01, episode reward = 100.0, ave reward = 114.0
# episode 54 of 300 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 115.0
# episode 55 of 300 complete,  explore val = 0.01, episode reward = 110.0, ave reward = 120.0
# episode 56 of 300 complete,  explore val = 0.01, episode reward = 242.0, ave reward = 121.1
# episode 57 of 300 complete,  explore val = 0.01, episode reward = 29.0, ave reward = 123.5
# episode 58 of 300 complete,  explore val = 0.01, episode reward = 258.0, ave reward = 123.8
# episode 59 of 300 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 126.4
# episode 60 of 300 complete,  explore val = 0.01, episode reward = 29.0, ave reward = 131.4
# episode 61 of 300 complete,  explore val = 0.01, episode reward = 91.0, ave reward = 131.7
# episode 62 of 300 complete,  explore val = 0.01, episode reward = 11.0, ave reward = 132.6
# episode 63 of 300 complete,  explore val = 0.01, episode reward = 176.0, ave reward = 132.7
# episode 64 of 300 complete,  explore val = 0.01, episode reward = 202.0, ave reward = 134.5
# episode 65 of 300 complete,  explore val = 0.01, episode reward = 31.0, ave reward = 136.5
# episode 66 of 300 complete,  explore val = 0.01, episode reward = 31.0, ave reward = 136.8
# episode 67 of 300 complete,  explore val = 0.01, episode reward = 36.0, ave reward = 137.1
# episode 68 of 300 complete,  explore val = 0.01, episode reward = 38.0, ave reward = 137.5
# episode 69 of 300 complete,  explore val = 0.01, episode reward = 11.0, ave reward = 137.8
# episode 70 of 300 complete,  explore val = 0.01, episode reward = 10.0, ave reward = 138.0
# episode 71 of 300 complete,  explore val = 0.01, episode reward = 12.0, ave reward = 138.0
# episode 72 of 300 complete,  explore val = 0.01, episode reward = 85.0, ave reward = 138.2
# episode 73 of 300 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 139.0
# episode 74 of 300 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 144.0
# episode 75 of 300 complete,  explore val = 0.01, episode reward = 91.0, ave reward = 149.0
# episode 76 of 300 complete,  explore val = 0.01, episode reward = 215.0, ave reward = 149.9
# episode 77 of 300 complete,  explore val = 0.01, episode reward = 19.0, ave reward = 152.1
# episode 78 of 300 complete,  explore val = 0.01, episode reward = 19.0, ave reward = 152.3
# episode 79 of 300 complete,  explore val = 0.01, episode reward = 12.0, ave reward = 152.5
# episode 80 of 300 complete,  explore val = 0.01, episode reward = 10.0, ave reward = 152.6
# episode 81 of 300 complete,  explore val = 0.01, episode reward = 10.0, ave reward = 152.7
# episode 82 of 300 complete,  explore val = 0.01, episode reward = 55.0, ave reward = 152.8
# episode 83 of 300 complete,  explore val = 0.01, episode reward = 202.0, ave reward = 153.3
# episode 84 of 300 complete,  explore val = 0.01, episode reward = 60.0, ave reward = 155.4
# episode 85 of 300 complete,  explore val = 0.01, episode reward = 41.0, ave reward = 156.0
# episode 86 of 300 complete,  explore val = 0.01, episode reward = 20.0, ave reward = 156.4
# episode 87 of 300 complete,  explore val = 0.01, episode reward = 29.0, ave reward = 156.6
# episode 88 of 300 complete,  explore val = 0.01, episode reward = 23.0, ave reward = 156.8
# episode 89 of 300 complete,  explore val = 0.01, episode reward = 11.0, ave reward = 157.1
# episode 90 of 300 complete,  explore val = 0.01, episode reward = 9.0, ave reward = 157.2
# episode 91 of 300 complete,  explore val = 0.01, episode reward = 9.0, ave reward = 157.3
# episode 92 of 300 complete,  explore val = 0.01, episode reward = 37.0, ave reward = 157.4
# episode 93 of 300 complete,  explore val = 0.01, episode reward = 54.0, ave reward = 157.7
# episode 94 of 300 complete,  explore val = 0.01, episode reward = 87.0, ave reward = 158.3
# episode 95 of 300 complete,  explore val = 0.01, episode reward = 416.0, ave reward = 159.2
# episode 96 of 300 complete,  explore val = 0.01, episode reward = 89.0, ave reward = 163.3
# episode 97 of 300 complete,  explore val = 0.01, episode reward = 124.0, ave reward = 164.2
# episode 98 of 300 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 165.4
# episode 99 of 300 complete,  explore val = 0.01, episode reward = 109.0, ave reward = 170.4
# episode 100 of 300 complete,  explore val = 0.01, episode reward = 137.0, ave reward = 171.5
# episode 101 of 300 complete,  explore val = 0.01, episode reward = 137.0, ave reward = 172.9
# episode 102 of 300 complete,  explore val = 0.01, episode reward = 117.0, ave reward = 174.2
# episode 103 of 300 complete,  explore val = 0.01, episode reward = 184.0, ave reward = 175.1
# episode 104 of 300 complete,  explore val = 0.01, episode reward = 99.0, ave reward = 176.8
# episode 105 of 300 complete,  explore val = 0.01, episode reward = 157.0, ave reward = 177.7
# episode 106 of 300 complete,  explore val = 0.01, episode reward = 81.0, ave reward = 178.9
# episode 107 of 300 complete,  explore val = 0.01, episode reward = 129.0, ave reward = 178.8
# episode 108 of 300 complete,  explore val = 0.01, episode reward = 129.0, ave reward = 179.6
# episode 109 of 300 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 180.5
# episode 110 of 300 complete,  explore val = 0.01, episode reward = 108.0, ave reward = 185.1
# episode 111 of 300 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 185.8
# episode 112 of 300 complete,  explore val = 0.01, episode reward = 151.0, ave reward = 190.0
# episode 113 of 300 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 191.1
# episode 114 of 300 complete,  explore val = 0.01, episode reward = 105.0, ave reward = 195.6
# episode 115 of 300 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 196.2
# episode 116 of 300 complete,  explore val = 0.01, episode reward = 107.0, ave reward = 196.2
# episode 117 of 300 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 196.3
# episode 118 of 300 complete,  explore val = 0.01, episode reward = 109.0, ave reward = 200.6
# q-learning algorithm complete

# %% [markdown]
# # plot total episode reward history

# %%
reward_logname = 'reward_logs/' + savename + '.txt'
plotter.plot_reward_history(reward_logname,window_length = exit_window)
