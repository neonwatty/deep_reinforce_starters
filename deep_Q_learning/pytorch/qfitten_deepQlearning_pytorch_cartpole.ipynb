# %% [markdown]
# # Q-Learner for cartpole

# %% [markdown]
# - Q-Learning algo written in PyTorch for the cartpole
#
# - Batch version used here, Q function updated after each episode of simulation

# %%
# imports
import os 
import sys
sys.path.append('../../')

# import custom reinforcement library
import reinforcement_library as reinlib

# import cartpole + pytorch online q-learner
learner = reinlib.deep_Q_Learning.qfitted_deepQlearning_pytorch
plotter = reinlib.deep_Q_Learning.history_plotter

# load in autoreload so any changes made to backend files mirrored in notebook
# without the need to restart kernel
# %load_ext autoreload
# %autoreload 2
# Out:
# Using TensorFlow backend.

# %% [markdown]
# - Q-Learner Algo can be loaded in from backend file by activating the command
#
# ```learner.QLearner??```
#
# in a code cell

# %% [markdown]
# ## Q Learning setup interface

# %%
# feed in current directory name and savename = experiment name
dirname = os.getcwd()
savename = 'qfitted_cartpole_experiment_1'
gymname = 'CartPole-v1'

# initialize Q Learn process
num_episodes = 500
explore_decay = 1
explore_val = 0.01
exit_level = 300
exit_window = 100

# initialize memory
episode_update = 1
memory_length = 1

# load into instance of learner
demo = learner.QLearner(gymname,dirname,savename,num_episodes=num_episodes,explore_decay=explore_decay,explore_val=explore_val,memory_length=memory_length,episode_update=episode_update,exit_level=exit_level,exit_window=exit_window)

# initialize Q function
layer_sizes = [100,100]
alpha = 10**(-2)
activation = 'relu'
demo.initialize_Q(layer_sizes=layer_sizes,alpha=alpha,activation=activation)
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
demo.train()
# Out:
# episode 1 of 500 complete,  explore val = 0.01, episode reward = 10.0, ave reward = 0.1
# episode 2 of 500 complete,  explore val = 0.01, episode reward = 26.0, ave reward = 0.4
# episode 3 of 500 complete,  explore val = 0.01, episode reward = 9.0, ave reward = 0.4
# episode 4 of 500 complete,  explore val = 0.01, episode reward = 9.0, ave reward = 0.5
# episode 5 of 500 complete,  explore val = 0.01, episode reward = 24.0, ave reward = 0.8
# episode 6 of 500 complete,  explore val = 0.01, episode reward = 10.0, ave reward = 0.9
# episode 7 of 500 complete,  explore val = 0.01, episode reward = 40.0, ave reward = 1.3
# episode 8 of 500 complete,  explore val = 0.01, episode reward = 9.0, ave reward = 1.4
# episode 9 of 500 complete,  explore val = 0.01, episode reward = 30.0, ave reward = 1.7
# episode 10 of 500 complete,  explore val = 0.01, episode reward = 31.0, ave reward = 2.0
# episode 11 of 500 complete,  explore val = 0.01, episode reward = 25.0, ave reward = 2.2
# episode 12 of 500 complete,  explore val = 0.01, episode reward = 81.0, ave reward = 3.0
# episode 13 of 500 complete,  explore val = 0.01, episode reward = 70.0, ave reward = 3.7
# episode 14 of 500 complete,  explore val = 0.01, episode reward = 81.0, ave reward = 4.6
# episode 15 of 500 complete,  explore val = 0.01, episode reward = 36.0, ave reward = 4.9
# episode 16 of 500 complete,  explore val = 0.01, episode reward = 27.0, ave reward = 5.2
# episode 17 of 500 complete,  explore val = 0.01, episode reward = 25.0, ave reward = 5.4
# episode 18 of 500 complete,  explore val = 0.01, episode reward = 17.0, ave reward = 5.6
# episode 19 of 500 complete,  explore val = 0.01, episode reward = 34.0, ave reward = 5.9
# episode 20 of 500 complete,  explore val = 0.01, episode reward = 306.0, ave reward = 9.0
# episode 21 of 500 complete,  explore val = 0.01, episode reward = 33.0, ave reward = 9.3
# episode 22 of 500 complete,  explore val = 0.01, episode reward = 23.0, ave reward = 9.6
# episode 23 of 500 complete,  explore val = 0.01, episode reward = 46.0, ave reward = 10.0
# episode 24 of 500 complete,  explore val = 0.01, episode reward = 30.0, ave reward = 10.3
# episode 25 of 500 complete,  explore val = 0.01, episode reward = 59.0, ave reward = 10.9
# episode 26 of 500 complete,  explore val = 0.01, episode reward = 43.0, ave reward = 11.3
# episode 27 of 500 complete,  explore val = 0.01, episode reward = 42.0, ave reward = 11.8
# episode 28 of 500 complete,  explore val = 0.01, episode reward = 28.0, ave reward = 12.0
# episode 29 of 500 complete,  explore val = 0.01, episode reward = 21.0, ave reward = 12.2
# episode 30 of 500 complete,  explore val = 0.01, episode reward = 33.0, ave reward = 12.6
# episode 31 of 500 complete,  explore val = 0.01, episode reward = 58.0, ave reward = 13.2
# episode 32 of 500 complete,  explore val = 0.01, episode reward = 150.0, ave reward = 14.7
# episode 33 of 500 complete,  explore val = 0.01, episode reward = 39.0, ave reward = 15.0
# episode 34 of 500 complete,  explore val = 0.01, episode reward = 110.0, ave reward = 16.2
# episode 35 of 500 complete,  explore val = 0.01, episode reward = 61.0, ave reward = 16.8
# episode 36 of 500 complete,  explore val = 0.01, episode reward = 73.0, ave reward = 17.5
# episode 37 of 500 complete,  explore val = 0.01, episode reward = 35.0, ave reward = 17.8
# episode 38 of 500 complete,  explore val = 0.01, episode reward = 41.0, ave reward = 18.2
# episode 39 of 500 complete,  explore val = 0.01, episode reward = 46.0, ave reward = 18.7
# episode 40 of 500 complete,  explore val = 0.01, episode reward = 34.0, ave reward = 19.0
# episode 41 of 500 complete,  explore val = 0.01, episode reward = 52.0, ave reward = 19.6
# episode 42 of 500 complete,  explore val = 0.01, episode reward = 68.0, ave reward = 20.2
# episode 43 of 500 complete,  explore val = 0.01, episode reward = 297.0, ave reward = 23.2
# episode 44 of 500 complete,  explore val = 0.01, episode reward = 35.0, ave reward = 23.6
# episode 45 of 500 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 28.6
# episode 46 of 500 complete,  explore val = 0.01, episode reward = 98.0, ave reward = 29.6
# episode 47 of 500 complete,  explore val = 0.01, episode reward = 54.0, ave reward = 30.1
# episode 48 of 500 complete,  explore val = 0.01, episode reward = 101.0, ave reward = 31.1
# episode 49 of 500 complete,  explore val = 0.01, episode reward = 35.0, ave reward = 31.4
# episode 50 of 500 complete,  explore val = 0.01, episode reward = 52.0, ave reward = 32.0
# episode 51 of 500 complete,  explore val = 0.01, episode reward = 41.0, ave reward = 32.4
# episode 52 of 500 complete,  explore val = 0.01, episode reward = 39.0, ave reward = 32.8
# episode 53 of 500 complete,  explore val = 0.01, episode reward = 36.0, ave reward = 33.1
# episode 54 of 500 complete,  explore val = 0.01, episode reward = 85.0, ave reward = 34.0
# episode 55 of 500 complete,  explore val = 0.01, episode reward = 109.0, ave reward = 35.1
# episode 56 of 500 complete,  explore val = 0.01, episode reward = 272.0, ave reward = 37.8
# episode 57 of 500 complete,  explore val = 0.01, episode reward = 54.0, ave reward = 38.3
# episode 58 of 500 complete,  explore val = 0.01, episode reward = 347.0, ave reward = 41.8
# episode 59 of 500 complete,  explore val = 0.01, episode reward = 66.0, ave reward = 42.5
# episode 60 of 500 complete,  explore val = 0.01, episode reward = 81.0, ave reward = 43.3
# episode 61 of 500 complete,  explore val = 0.01, episode reward = 41.0, ave reward = 43.7
# episode 62 of 500 complete,  explore val = 0.01, episode reward = 48.0, ave reward = 44.2
# episode 63 of 500 complete,  explore val = 0.01, episode reward = 253.0, ave reward = 46.7
# episode 64 of 500 complete,  explore val = 0.01, episode reward = 47.0, ave reward = 47.2
# episode 65 of 500 complete,  explore val = 0.01, episode reward = 281.0, ave reward = 50.0
# episode 66 of 500 complete,  explore val = 0.01, episode reward = 271.0, ave reward = 52.7
# episode 67 of 500 complete,  explore val = 0.01, episode reward = 245.0, ave reward = 55.1
# episode 68 of 500 complete,  explore val = 0.01, episode reward = 65.0, ave reward = 55.8
# episode 69 of 500 complete,  explore val = 0.01, episode reward = 52.0, ave reward = 56.3
# episode 70 of 500 complete,  explore val = 0.01, episode reward = 207.0, ave reward = 58.4
# episode 71 of 500 complete,  explore val = 0.01, episode reward = 199.0, ave reward = 60.4
# episode 72 of 500 complete,  explore val = 0.01, episode reward = 156.0, ave reward = 61.9
# episode 73 of 500 complete,  explore val = 0.01, episode reward = 62.0, ave reward = 62.5
# episode 74 of 500 complete,  explore val = 0.01, episode reward = 50.0, ave reward = 63.0
# episode 75 of 500 complete,  explore val = 0.01, episode reward = 60.0, ave reward = 63.6
# episode 76 of 500 complete,  explore val = 0.01, episode reward = 60.0, ave reward = 64.2
# episode 77 of 500 complete,  explore val = 0.01, episode reward = 188.0, ave reward = 66.1
# episode 78 of 500 complete,  explore val = 0.01, episode reward = 28.0, ave reward = 66.4
# episode 79 of 500 complete,  explore val = 0.01, episode reward = 50.0, ave reward = 66.9
# episode 80 of 500 complete,  explore val = 0.01, episode reward = 87.0, ave reward = 67.8
# episode 81 of 500 complete,  explore val = 0.01, episode reward = 49.0, ave reward = 68.3
# episode 82 of 500 complete,  explore val = 0.01, episode reward = 465.0, ave reward = 72.9
# episode 83 of 500 complete,  explore val = 0.01, episode reward = 55.0, ave reward = 73.5
# episode 84 of 500 complete,  explore val = 0.01, episode reward = 140.0, ave reward = 74.9
# episode 85 of 500 complete,  explore val = 0.01, episode reward = 145.0, ave reward = 76.3
# episode 86 of 500 complete,  explore val = 0.01, episode reward = 126.0, ave reward = 77.6
# episode 87 of 500 complete,  explore val = 0.01, episode reward = 77.0, ave reward = 78.3
# episode 88 of 500 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 83.3
# episode 89 of 500 complete,  explore val = 0.01, episode reward = 456.0, ave reward = 87.9
# episode 90 of 500 complete,  explore val = 0.01, episode reward = 192.0, ave reward = 89.8
# episode 91 of 500 complete,  explore val = 0.01, episode reward = 200.0, ave reward = 91.8
# episode 92 of 500 complete,  explore val = 0.01, episode reward = 54.0, ave reward = 92.4
# episode 93 of 500 complete,  explore val = 0.01, episode reward = 365.0, ave reward = 96.0
# episode 94 of 500 complete,  explore val = 0.01, episode reward = 115.0, ave reward = 97.2
# episode 95 of 500 complete,  explore val = 0.01, episode reward = 147.0, ave reward = 98.6
# episode 96 of 500 complete,  explore val = 0.01, episode reward = 145.0, ave reward = 100.1
# episode 97 of 500 complete,  explore val = 0.01, episode reward = 356.0, ave reward = 103.6
# episode 98 of 500 complete,  explore val = 0.01, episode reward = 173.0, ave reward = 105.4
# episode 99 of 500 complete,  explore val = 0.01, episode reward = 110.0, ave reward = 106.5
# episode 100 of 500 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 111.5
# episode 101 of 500 complete,  explore val = 0.01, episode reward = 289.0, ave reward = 114.3
# episode 102 of 500 complete,  explore val = 0.01, episode reward = 281.0, ave reward = 116.8
# episode 103 of 500 complete,  explore val = 0.01, episode reward = 135.0, ave reward = 118.1
# episode 104 of 500 complete,  explore val = 0.01, episode reward = 128.0, ave reward = 119.3
# episode 105 of 500 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 124.0
# episode 106 of 500 complete,  explore val = 0.01, episode reward = 125.0, ave reward = 125.2
# episode 107 of 500 complete,  explore val = 0.01, episode reward = 111.0, ave reward = 125.9
# episode 108 of 500 complete,  explore val = 0.01, episode reward = 103.0, ave reward = 126.8
# episode 109 of 500 complete,  explore val = 0.01, episode reward = 76.0, ave reward = 127.3
# episode 110 of 500 complete,  explore val = 0.01, episode reward = 91.0, ave reward = 127.9
# episode 111 of 500 complete,  explore val = 0.01, episode reward = 104.0, ave reward = 128.7
# episode 112 of 500 complete,  explore val = 0.01, episode reward = 90.0, ave reward = 128.8
# episode 113 of 500 complete,  explore val = 0.01, episode reward = 89.0, ave reward = 129.0
# episode 114 of 500 complete,  explore val = 0.01, episode reward = 71.0, ave reward = 128.8
# episode 115 of 500 complete,  explore val = 0.01, episode reward = 210.0, ave reward = 130.6
# episode 116 of 500 complete,  explore val = 0.01, episode reward = 91.0, ave reward = 131.2
# episode 117 of 500 complete,  explore val = 0.01, episode reward = 368.0, ave reward = 134.7
# episode 118 of 500 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 139.5
# episode 119 of 500 complete,  explore val = 0.01, episode reward = 337.0, ave reward = 142.5
# episode 120 of 500 complete,  explore val = 0.01, episode reward = 65.0, ave reward = 140.1
# episode 121 of 500 complete,  explore val = 0.01, episode reward = 87.0, ave reward = 140.6
# episode 122 of 500 complete,  explore val = 0.01, episode reward = 293.0, ave reward = 143.4
# episode 123 of 500 complete,  explore val = 0.01, episode reward = 64.0, ave reward = 143.5
# episode 124 of 500 complete,  explore val = 0.01, episode reward = 177.0, ave reward = 145.0
# episode 125 of 500 complete,  explore val = 0.01, episode reward = 60.0, ave reward = 145.0
# episode 126 of 500 complete,  explore val = 0.01, episode reward = 49.0, ave reward = 145.1
# episode 127 of 500 complete,  explore val = 0.01, episode reward = 43.0, ave reward = 145.1
# episode 128 of 500 complete,  explore val = 0.01, episode reward = 262.0, ave reward = 147.4
# episode 129 of 500 complete,  explore val = 0.01, episode reward = 41.0, ave reward = 147.6
# episode 130 of 500 complete,  explore val = 0.01, episode reward = 90.0, ave reward = 148.2
# episode 131 of 500 complete,  explore val = 0.01, episode reward = 193.0, ave reward = 149.5
# episode 132 of 500 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 153.0
# episode 133 of 500 complete,  explore val = 0.01, episode reward = 464.0, ave reward = 157.3
# episode 134 of 500 complete,  explore val = 0.01, episode reward = 261.0, ave reward = 158.8
# episode 135 of 500 complete,  explore val = 0.01, episode reward = 94.0, ave reward = 159.1
# episode 136 of 500 complete,  explore val = 0.01, episode reward = 78.0, ave reward = 159.2
# episode 137 of 500 complete,  explore val = 0.01, episode reward = 189.0, ave reward = 160.7
# episode 138 of 500 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 165.3
# episode 139 of 500 complete,  explore val = 0.01, episode reward = 161.0, ave reward = 166.5
# episode 140 of 500 complete,  explore val = 0.01, episode reward = 266.0, ave reward = 168.8
# episode 141 of 500 complete,  explore val = 0.01, episode reward = 228.0, ave reward = 170.5
# episode 142 of 500 complete,  explore val = 0.01, episode reward = 48.0, ave reward = 170.3
# episode 143 of 500 complete,  explore val = 0.01, episode reward = 88.0, ave reward = 168.2
# episode 144 of 500 complete,  explore val = 0.01, episode reward = 230.0, ave reward = 170.2
# episode 145 of 500 complete,  explore val = 0.01, episode reward = 239.0, ave reward = 167.6
# episode 146 of 500 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 171.6
# episode 147 of 500 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 176.1
# episode 148 of 500 complete,  explore val = 0.01, episode reward = 371.0, ave reward = 178.8
# episode 149 of 500 complete,  explore val = 0.01, episode reward = 219.0, ave reward = 180.6
# episode 150 of 500 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 185.1
# episode 151 of 500 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 189.7
# episode 152 of 500 complete,  explore val = 0.01, episode reward = 282.0, ave reward = 192.1
# episode 153 of 500 complete,  explore val = 0.01, episode reward = 307.0, ave reward = 194.8
# episode 154 of 500 complete,  explore val = 0.01, episode reward = 243.0, ave reward = 196.4
# episode 155 of 500 complete,  explore val = 0.01, episode reward = 329.0, ave reward = 198.6
# episode 156 of 500 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 200.9
# episode 157 of 500 complete,  explore val = 0.01, episode reward = 328.0, ave reward = 203.6
# episode 158 of 500 complete,  explore val = 0.01, episode reward = 227.0, ave reward = 202.4
# episode 159 of 500 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 206.8
# episode 160 of 500 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 211.0
# episode 161 of 500 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 215.5
# episode 162 of 500 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 220.1
# episode 163 of 500 complete,  explore val = 0.01, episode reward = 139.0, ave reward = 218.9
# episode 164 of 500 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 223.4
# episode 165 of 500 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 225.6
# episode 166 of 500 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 227.9
# episode 167 of 500 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 230.5
# episode 168 of 500 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 234.8
# episode 169 of 500 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 239.3
# episode 170 of 500 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 242.2
# episode 171 of 500 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 245.2
# episode 172 of 500 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 248.7
# episode 173 of 500 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 253.1
# episode 174 of 500 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 257.6
# episode 175 of 500 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 262.0
# episode 176 of 500 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 266.4
# episode 177 of 500 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 269.5
# episode 178 of 500 complete,  explore val = 0.01, episode reward = 13.0, ave reward = 269.3
# episode 179 of 500 complete,  explore val = 0.01, episode reward = 9.0, ave reward = 268.9
# episode 180 of 500 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 273.1
# episode 181 of 500 complete,  explore val = 0.01, episode reward = 28.0, ave reward = 272.8
# episode 182 of 500 complete,  explore val = 0.01, episode reward = 9.0, ave reward = 268.3
# episode 183 of 500 complete,  explore val = 0.01, episode reward = 9.0, ave reward = 267.8
# episode 184 of 500 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 271.4
# episode 185 of 500 complete,  explore val = 0.01, episode reward = 28.0, ave reward = 270.3
# episode 186 of 500 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 274.0
# episode 187 of 500 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 278.2
# episode 188 of 500 complete,  explore val = 0.01, episode reward = 364.0, ave reward = 276.9
# episode 189 of 500 complete,  explore val = 0.01, episode reward = 233.0, ave reward = 274.6
# episode 190 of 500 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 277.7
# episode 191 of 500 complete,  explore val = 0.01, episode reward = 426.0, ave reward = 280.0
# episode 192 of 500 complete,  explore val = 0.01, episode reward = 369.0, ave reward = 283.1
# episode 193 of 500 complete,  explore val = 0.01, episode reward = 413.0, ave reward = 283.6
# episode 194 of 500 complete,  explore val = 0.01, episode reward = 324.0, ave reward = 285.7
# episode 195 of 500 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 289.2
# episode 196 of 500 complete,  explore val = 0.01, episode reward = 492.0, ave reward = 292.7
# episode 197 of 500 complete,  explore val = 0.01, episode reward = 423.0, ave reward = 293.4
# episode 198 of 500 complete,  explore val = 0.01, episode reward = 378.0, ave reward = 295.4
# episode 199 of 500 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 299.3
# episode 200 of 500 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 299.3
# episode 201 of 500 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 301.4
# q-learning algorithm complete

# %% [markdown]
# # plot total episode reward history

# %%
reward_logname = 'reward_logs/' + savename + '.txt'
plotter.plot_reward_history(reward_logname,window_length = exit_window)
