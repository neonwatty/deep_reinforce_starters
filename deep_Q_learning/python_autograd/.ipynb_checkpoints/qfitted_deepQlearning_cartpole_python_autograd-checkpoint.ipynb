# %% [markdown]
# # Run test

# %% [markdown]
# - Q-Learning algo written in PyTorch for the cartpole
#
# - Batch version used here, Q function updated after each episode of simulation

# %%
# imports
import os 
import sys
sys.path.append('../../')

# import custom reinforcement library
import reinforcement_library as reinlib

# import cartpole + pytorch online q-learner
learner = reinlib.deep_Q_Learning.qfitted_deepQlearning_python_autograd
plotter = reinlib.deep_Q_Learning.history_plotter

# load in autoreload so any changes made to backend files mirrored in notebook
# without the need to restart kernel
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# - Q-Learner Algo can be loaded in from backend file by activating the command
#
# ```learner.QLearner??```
#
# in a code cell

# %% [markdown]
# ## Q Learning setup interface

# %%
# feed in current directory name and savename = experiment name
dirname = os.getcwd()
savename = 'qfitted_cartpole_experiment_1'
gymname = 'CartPole-v1'

# initialize Q Learn process
num_episodes = 1000
explore_decay = 1
explore_val = 0.01
exit_level = 200
exit_window = 100

# initialize memory
episode_update = 1
memory_length = 1

# load into instance of learner
demo = learner.QLearner(gymname,dirname,savename,num_episodes=num_episodes,explore_decay=explore_decay,explore_val=explore_val,memory_length=memory_length,episode_update=episode_update,exit_level=exit_level,exit_window=exit_window)

# initialize Q function
layer_sizes = [50,50]
alpha = 10**(-2)
activation = 'relu'
demo.initialize_Q(layer_sizes=layer_sizes,alpha=alpha,activation=activation)
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
demo.train(verbose = True)
# Out:
# episode 1 of 1000 complete,  explore val = 0.01, episode reward = 15.0, ave reward = 0.2
# episode 2 of 1000 complete,  explore val = 0.01, episode reward = 9.0, ave reward = 0.2
# episode 3 of 1000 complete,  explore val = 0.01, episode reward = 20.0, ave reward = 0.4
# episode 4 of 1000 complete,  explore val = 0.01, episode reward = 12.0, ave reward = 0.6
# episode 5 of 1000 complete,  explore val = 0.01, episode reward = 8.0, ave reward = 0.6
# episode 6 of 1000 complete,  explore val = 0.01, episode reward = 13.0, ave reward = 0.8
# episode 7 of 1000 complete,  explore val = 0.01, episode reward = 59.0, ave reward = 1.4
# episode 8 of 1000 complete,  explore val = 0.01, episode reward = 45.0, ave reward = 1.8
# episode 9 of 1000 complete,  explore val = 0.01, episode reward = 105.0, ave reward = 2.9
# episode 10 of 1000 complete,  explore val = 0.01, episode reward = 33.0, ave reward = 3.2
# episode 11 of 1000 complete,  explore val = 0.01, episode reward = 34.0, ave reward = 3.5
# episode 12 of 1000 complete,  explore val = 0.01, episode reward = 23.0, ave reward = 3.8
# episode 13 of 1000 complete,  explore val = 0.01, episode reward = 92.0, ave reward = 4.7
# episode 14 of 1000 complete,  explore val = 0.01, episode reward = 100.0, ave reward = 5.7
# episode 15 of 1000 complete,  explore val = 0.01, episode reward = 123.0, ave reward = 6.9
# episode 16 of 1000 complete,  explore val = 0.01, episode reward = 41.0, ave reward = 7.3
# episode 17 of 1000 complete,  explore val = 0.01, episode reward = 23.0, ave reward = 7.6
# episode 18 of 1000 complete,  explore val = 0.01, episode reward = 67.0, ave reward = 8.2
# episode 19 of 1000 complete,  explore val = 0.01, episode reward = 34.0, ave reward = 8.6
# episode 20 of 1000 complete,  explore val = 0.01, episode reward = 23.0, ave reward = 8.8
# episode 21 of 1000 complete,  explore val = 0.01, episode reward = 59.0, ave reward = 9.4
# episode 22 of 1000 complete,  explore val = 0.01, episode reward = 36.0, ave reward = 9.7
# episode 23 of 1000 complete,  explore val = 0.01, episode reward = 20.0, ave reward = 9.9
# episode 24 of 1000 complete,  explore val = 0.01, episode reward = 10.0, ave reward = 10.0
# episode 25 of 1000 complete,  explore val = 0.01, episode reward = 29.0, ave reward = 10.3
# episode 26 of 1000 complete,  explore val = 0.01, episode reward = 51.0, ave reward = 10.8
# episode 27 of 1000 complete,  explore val = 0.01, episode reward = 24.0, ave reward = 11.1
# episode 28 of 1000 complete,  explore val = 0.01, episode reward = 50.0, ave reward = 11.6
# episode 29 of 1000 complete,  explore val = 0.01, episode reward = 22.0, ave reward = 11.8
# episode 30 of 1000 complete,  explore val = 0.01, episode reward = 9.0, ave reward = 11.9
# episode 31 of 1000 complete,  explore val = 0.01, episode reward = 37.0, ave reward = 12.3
# episode 32 of 1000 complete,  explore val = 0.01, episode reward = 15.0, ave reward = 12.4
# episode 33 of 1000 complete,  explore val = 0.01, episode reward = 9.0, ave reward = 12.5
# episode 34 of 1000 complete,  explore val = 0.01, episode reward = 15.0, ave reward = 12.6
# episode 35 of 1000 complete,  explore val = 0.01, episode reward = 29.0, ave reward = 12.9
# episode 36 of 1000 complete,  explore val = 0.01, episode reward = 24.0, ave reward = 13.2
# episode 37 of 1000 complete,  explore val = 0.01, episode reward = 42.0, ave reward = 13.6
# episode 38 of 1000 complete,  explore val = 0.01, episode reward = 23.0, ave reward = 13.8
# episode 39 of 1000 complete,  explore val = 0.01, episode reward = 46.0, ave reward = 14.3
# episode 40 of 1000 complete,  explore val = 0.01, episode reward = 31.0, ave reward = 14.6
# episode 41 of 1000 complete,  explore val = 0.01, episode reward = 14.0, ave reward = 14.7
# episode 42 of 1000 complete,  explore val = 0.01, episode reward = 10.0, ave reward = 14.8
# episode 43 of 1000 complete,  explore val = 0.01, episode reward = 16.0, ave reward = 15.0
# episode 44 of 1000 complete,  explore val = 0.01, episode reward = 9.0, ave reward = 15.1
# episode 45 of 1000 complete,  explore val = 0.01, episode reward = 19.0, ave reward = 15.3
# episode 46 of 1000 complete,  explore val = 0.01, episode reward = 26.0, ave reward = 15.5
# episode 47 of 1000 complete,  explore val = 0.01, episode reward = 72.0, ave reward = 16.3
# episode 48 of 1000 complete,  explore val = 0.01, episode reward = 84.0, ave reward = 17.1
# episode 49 of 1000 complete,  explore val = 0.01, episode reward = 27.0, ave reward = 17.4
# episode 50 of 1000 complete,  explore val = 0.01, episode reward = 13.0, ave reward = 17.5
# episode 51 of 1000 complete,  explore val = 0.01, episode reward = 10.0, ave reward = 17.6
# episode 52 of 1000 complete,  explore val = 0.01, episode reward = 11.0, ave reward = 17.7
# episode 53 of 1000 complete,  explore val = 0.01, episode reward = 9.0, ave reward = 17.8
# episode 54 of 1000 complete,  explore val = 0.01, episode reward = 9.0, ave reward = 17.9
# episode 55 of 1000 complete,  explore val = 0.01, episode reward = 8.0, ave reward = 18.0
# episode 56 of 1000 complete,  explore val = 0.01, episode reward = 10.0, ave reward = 18.1
# episode 57 of 1000 complete,  explore val = 0.01, episode reward = 40.0, ave reward = 18.5
# episode 58 of 1000 complete,  explore val = 0.01, episode reward = 12.0, ave reward = 18.6
# episode 59 of 1000 complete,  explore val = 0.01, episode reward = 10.0, ave reward = 18.7
# episode 60 of 1000 complete,  explore val = 0.01, episode reward = 14.0, ave reward = 18.8
# episode 61 of 1000 complete,  explore val = 0.01, episode reward = 9.0, ave reward = 18.9
# episode 62 of 1000 complete,  explore val = 0.01, episode reward = 12.0, ave reward = 19.0
# episode 63 of 1000 complete,  explore val = 0.01, episode reward = 11.0, ave reward = 19.2
# episode 64 of 1000 complete,  explore val = 0.01, episode reward = 22.0, ave reward = 19.4
# episode 65 of 1000 complete,  explore val = 0.01, episode reward = 9.0, ave reward = 19.5
# episode 66 of 1000 complete,  explore val = 0.01, episode reward = 10.0, ave reward = 19.6
# episode 67 of 1000 complete,  explore val = 0.01, episode reward = 10.0, ave reward = 19.7
# episode 68 of 1000 complete,  explore val = 0.01, episode reward = 21.0, ave reward = 19.9
# episode 69 of 1000 complete,  explore val = 0.01, episode reward = 9.0, ave reward = 20.0
# episode 70 of 1000 complete,  explore val = 0.01, episode reward = 33.0, ave reward = 20.3
# episode 71 of 1000 complete,  explore val = 0.01, episode reward = 55.0, ave reward = 20.8
# episode 72 of 1000 complete,  explore val = 0.01, episode reward = 10.0, ave reward = 20.9
# episode 73 of 1000 complete,  explore val = 0.01, episode reward = 156.0, ave reward = 22.5
# episode 74 of 1000 complete,  explore val = 0.01, episode reward = 20.0, ave reward = 22.7
# episode 75 of 1000 complete,  explore val = 0.01, episode reward = 9.0, ave reward = 22.8
# episode 76 of 1000 complete,  explore val = 0.01, episode reward = 94.0, ave reward = 23.7
# episode 77 of 1000 complete,  explore val = 0.01, episode reward = 9.0, ave reward = 23.8
# episode 78 of 1000 complete,  explore val = 0.01, episode reward = 24.0, ave reward = 24.1
# episode 79 of 1000 complete,  explore val = 0.01, episode reward = 9.0, ave reward = 24.2
# episode 80 of 1000 complete,  explore val = 0.01, episode reward = 16.0, ave reward = 24.3
# episode 81 of 1000 complete,  explore val = 0.01, episode reward = 15.0, ave reward = 24.5
# episode 82 of 1000 complete,  explore val = 0.01, episode reward = 19.0, ave reward = 24.6
# episode 83 of 1000 complete,  explore val = 0.01, episode reward = 18.0, ave reward = 24.8
# episode 84 of 1000 complete,  explore val = 0.01, episode reward = 16.0, ave reward = 25.0
# episode 85 of 1000 complete,  explore val = 0.01, episode reward = 16.0, ave reward = 25.2
# episode 86 of 1000 complete,  explore val = 0.01, episode reward = 23.0, ave reward = 25.4
# episode 87 of 1000 complete,  explore val = 0.01, episode reward = 15.0, ave reward = 25.5
# episode 88 of 1000 complete,  explore val = 0.01, episode reward = 26.0, ave reward = 25.8
# episode 89 of 1000 complete,  explore val = 0.01, episode reward = 17.0, ave reward = 26.0
# episode 90 of 1000 complete,  explore val = 0.01, episode reward = 22.0, ave reward = 26.2
# episode 91 of 1000 complete,  explore val = 0.01, episode reward = 27.0, ave reward = 26.4
# episode 92 of 1000 complete,  explore val = 0.01, episode reward = 35.0, ave reward = 26.8
# episode 93 of 1000 complete,  explore val = 0.01, episode reward = 113.0, ave reward = 27.9
# episode 94 of 1000 complete,  explore val = 0.01, episode reward = 14.0, ave reward = 28.1
# episode 95 of 1000 complete,  explore val = 0.01, episode reward = 17.0, ave reward = 28.2
# episode 96 of 1000 complete,  explore val = 0.01, episode reward = 23.0, ave reward = 28.5
# episode 97 of 1000 complete,  explore val = 0.01, episode reward = 24.0, ave reward = 28.7
# episode 98 of 1000 complete,  explore val = 0.01, episode reward = 94.0, ave reward = 29.6
# episode 99 of 1000 complete,  explore val = 0.01, episode reward = 38.0, ave reward = 30.0
# episode 100 of 1000 complete,  explore val = 0.01, episode reward = 13.0, ave reward = 30.2
# episode 101 of 1000 complete,  explore val = 0.01, episode reward = 38.0, ave reward = 30.4
# episode 102 of 1000 complete,  explore val = 0.01, episode reward = 16.0, ave reward = 30.5
# episode 103 of 1000 complete,  explore val = 0.01, episode reward = 55.0, ave reward = 30.8
# episode 104 of 1000 complete,  explore val = 0.01, episode reward = 20.0, ave reward = 30.9
# episode 105 of 1000 complete,  explore val = 0.01, episode reward = 17.0, ave reward = 31.0
# episode 106 of 1000 complete,  explore val = 0.01, episode reward = 33.0, ave reward = 31.2
# episode 107 of 1000 complete,  explore val = 0.01, episode reward = 14.0, ave reward = 30.7
# episode 108 of 1000 complete,  explore val = 0.01, episode reward = 99.0, ave reward = 31.3
# episode 109 of 1000 complete,  explore val = 0.01, episode reward = 61.0, ave reward = 30.8
# episode 110 of 1000 complete,  explore val = 0.01, episode reward = 70.0, ave reward = 31.2
# episode 111 of 1000 complete,  explore val = 0.01, episode reward = 30.0, ave reward = 31.2
# episode 112 of 1000 complete,  explore val = 0.01, episode reward = 20.0, ave reward = 31.1
# episode 113 of 1000 complete,  explore val = 0.01, episode reward = 22.0, ave reward = 30.4
# episode 114 of 1000 complete,  explore val = 0.01, episode reward = 27.0, ave reward = 29.7
# episode 115 of 1000 complete,  explore val = 0.01, episode reward = 11.0, ave reward = 28.6
# episode 116 of 1000 complete,  explore val = 0.01, episode reward = 77.0, ave reward = 28.9
# episode 117 of 1000 complete,  explore val = 0.01, episode reward = 23.0, ave reward = 28.9
# episode 118 of 1000 complete,  explore val = 0.01, episode reward = 10.0, ave reward = 28.4
# episode 119 of 1000 complete,  explore val = 0.01, episode reward = 19.0, ave reward = 28.2
# episode 120 of 1000 complete,  explore val = 0.01, episode reward = 47.0, ave reward = 28.5
# episode 121 of 1000 complete,  explore val = 0.01, episode reward = 76.0, ave reward = 28.6
# episode 122 of 1000 complete,  explore val = 0.01, episode reward = 71.0, ave reward = 29.0
# episode 123 of 1000 complete,  explore val = 0.01, episode reward = 24.0, ave reward = 29.0
# episode 124 of 1000 complete,  explore val = 0.01, episode reward = 17.0, ave reward = 29.1
# episode 125 of 1000 complete,  explore val = 0.01, episode reward = 47.0, ave reward = 29.3
# episode 126 of 1000 complete,  explore val = 0.01, episode reward = 64.0, ave reward = 29.4
# episode 127 of 1000 complete,  explore val = 0.01, episode reward = 27.0, ave reward = 29.4
# episode 128 of 1000 complete,  explore val = 0.01, episode reward = 43.0, ave reward = 29.4
# episode 129 of 1000 complete,  explore val = 0.01, episode reward = 84.0, ave reward = 30.0
# episode 130 of 1000 complete,  explore val = 0.01, episode reward = 82.0, ave reward = 30.7
# episode 131 of 1000 complete,  explore val = 0.01, episode reward = 38.0, ave reward = 30.7
# episode 132 of 1000 complete,  explore val = 0.01, episode reward = 17.0, ave reward = 30.7
# episode 133 of 1000 complete,  explore val = 0.01, episode reward = 21.0, ave reward = 30.9
# episode 134 of 1000 complete,  explore val = 0.01, episode reward = 26.0, ave reward = 31.0
# episode 135 of 1000 complete,  explore val = 0.01, episode reward = 34.0, ave reward = 31.0
# episode 136 of 1000 complete,  explore val = 0.01, episode reward = 38.0, ave reward = 31.2
# episode 137 of 1000 complete,  explore val = 0.01, episode reward = 16.0, ave reward = 30.9
# episode 138 of 1000 complete,  explore val = 0.01, episode reward = 95.0, ave reward = 31.6
# episode 139 of 1000 complete,  explore val = 0.01, episode reward = 26.0, ave reward = 31.4
# episode 140 of 1000 complete,  explore val = 0.01, episode reward = 51.0, ave reward = 31.6
# episode 141 of 1000 complete,  explore val = 0.01, episode reward = 75.0, ave reward = 32.2
# episode 142 of 1000 complete,  explore val = 0.01, episode reward = 16.0, ave reward = 32.3
# episode 143 of 1000 complete,  explore val = 0.01, episode reward = 13.0, ave reward = 32.3
# episode 144 of 1000 complete,  explore val = 0.01, episode reward = 20.0, ave reward = 32.4
# episode 145 of 1000 complete,  explore val = 0.01, episode reward = 38.0, ave reward = 32.6
# episode 146 of 1000 complete,  explore val = 0.01, episode reward = 42.0, ave reward = 32.7
# episode 147 of 1000 complete,  explore val = 0.01, episode reward = 15.0, ave reward = 32.2
# episode 148 of 1000 complete,  explore val = 0.01, episode reward = 70.0, ave reward = 32.0
# episode 149 of 1000 complete,  explore val = 0.01, episode reward = 103.0, ave reward = 32.8
# episode 150 of 1000 complete,  explore val = 0.01, episode reward = 53.0, ave reward = 33.2
# episode 151 of 1000 complete,  explore val = 0.01, episode reward = 41.0, ave reward = 33.5
# episode 152 of 1000 complete,  explore val = 0.01, episode reward = 29.0, ave reward = 33.7
# episode 153 of 1000 complete,  explore val = 0.01, episode reward = 37.0, ave reward = 33.9
# episode 154 of 1000 complete,  explore val = 0.01, episode reward = 19.0, ave reward = 34.0
# episode 155 of 1000 complete,  explore val = 0.01, episode reward = 14.0, ave reward = 34.1
# episode 156 of 1000 complete,  explore val = 0.01, episode reward = 135.0, ave reward = 35.4
# episode 157 of 1000 complete,  explore val = 0.01, episode reward = 22.0, ave reward = 35.2
# episode 158 of 1000 complete,  explore val = 0.01, episode reward = 80.0, ave reward = 35.8
# episode 159 of 1000 complete,  explore val = 0.01, episode reward = 29.0, ave reward = 36.0
# episode 160 of 1000 complete,  explore val = 0.01, episode reward = 43.0, ave reward = 36.3
# episode 161 of 1000 complete,  explore val = 0.01, episode reward = 39.0, ave reward = 36.6
# episode 162 of 1000 complete,  explore val = 0.01, episode reward = 36.0, ave reward = 36.9
# episode 163 of 1000 complete,  explore val = 0.01, episode reward = 31.0, ave reward = 37.1
# episode 164 of 1000 complete,  explore val = 0.01, episode reward = 27.0, ave reward = 37.1
# episode 165 of 1000 complete,  explore val = 0.01, episode reward = 48.0, ave reward = 37.5
# episode 166 of 1000 complete,  explore val = 0.01, episode reward = 160.0, ave reward = 39.0
# episode 167 of 1000 complete,  explore val = 0.01, episode reward = 47.0, ave reward = 39.4
# episode 168 of 1000 complete,  explore val = 0.01, episode reward = 24.0, ave reward = 39.4
# episode 169 of 1000 complete,  explore val = 0.01, episode reward = 21.0, ave reward = 39.5
# episode 170 of 1000 complete,  explore val = 0.01, episode reward = 45.0, ave reward = 39.6
# episode 171 of 1000 complete,  explore val = 0.01, episode reward = 27.0, ave reward = 39.4
# episode 172 of 1000 complete,  explore val = 0.01, episode reward = 130.0, ave reward = 40.6
# episode 173 of 1000 complete,  explore val = 0.01, episode reward = 38.0, ave reward = 39.4
# episode 174 of 1000 complete,  explore val = 0.01, episode reward = 81.0, ave reward = 40.0
# episode 175 of 1000 complete,  explore val = 0.01, episode reward = 47.0, ave reward = 40.4
# episode 176 of 1000 complete,  explore val = 0.01, episode reward = 46.0, ave reward = 39.9
# episode 177 of 1000 complete,  explore val = 0.01, episode reward = 26.0, ave reward = 40.1
# episode 178 of 1000 complete,  explore val = 0.01, episode reward = 19.0, ave reward = 40.0
# episode 179 of 1000 complete,  explore val = 0.01, episode reward = 30.0, ave reward = 40.2
# episode 180 of 1000 complete,  explore val = 0.01, episode reward = 19.0, ave reward = 40.3
# episode 181 of 1000 complete,  explore val = 0.01, episode reward = 97.0, ave reward = 41.1
# episode 182 of 1000 complete,  explore val = 0.01, episode reward = 48.0, ave reward = 41.4
# episode 183 of 1000 complete,  explore val = 0.01, episode reward = 22.0, ave reward = 41.4
# episode 184 of 1000 complete,  explore val = 0.01, episode reward = 17.0, ave reward = 41.4
# episode 185 of 1000 complete,  explore val = 0.01, episode reward = 21.0, ave reward = 41.5
# episode 186 of 1000 complete,  explore val = 0.01, episode reward = 64.0, ave reward = 41.9
# episode 187 of 1000 complete,  explore val = 0.01, episode reward = 43.0, ave reward = 42.2
# episode 188 of 1000 complete,  explore val = 0.01, episode reward = 33.0, ave reward = 42.2
# episode 189 of 1000 complete,  explore val = 0.01, episode reward = 40.0, ave reward = 42.5
# episode 190 of 1000 complete,  explore val = 0.01, episode reward = 67.0, ave reward = 42.9
# episode 191 of 1000 complete,  explore val = 0.01, episode reward = 110.0, ave reward = 43.7
# episode 192 of 1000 complete,  explore val = 0.01, episode reward = 52.0, ave reward = 43.9
# episode 193 of 1000 complete,  explore val = 0.01, episode reward = 36.0, ave reward = 43.1
# episode 194 of 1000 complete,  explore val = 0.01, episode reward = 20.0, ave reward = 43.2
# episode 195 of 1000 complete,  explore val = 0.01, episode reward = 18.0, ave reward = 43.2
# episode 196 of 1000 complete,  explore val = 0.01, episode reward = 59.0, ave reward = 43.6
# episode 197 of 1000 complete,  explore val = 0.01, episode reward = 37.0, ave reward = 43.7
# episode 198 of 1000 complete,  explore val = 0.01, episode reward = 29.0, ave reward = 43.0
# episode 199 of 1000 complete,  explore val = 0.01, episode reward = 57.0, ave reward = 43.2
# episode 200 of 1000 complete,  explore val = 0.01, episode reward = 24.0, ave reward = 43.4
# episode 201 of 1000 complete,  explore val = 0.01, episode reward = 412.0, ave reward = 47.1
# episode 202 of 1000 complete,  explore val = 0.01, episode reward = 59.0, ave reward = 47.5
# episode 203 of 1000 complete,  explore val = 0.01, episode reward = 17.0, ave reward = 47.1
# episode 204 of 1000 complete,  explore val = 0.01, episode reward = 20.0, ave reward = 47.1
# episode 205 of 1000 complete,  explore val = 0.01, episode reward = 58.0, ave reward = 47.6
# episode 206 of 1000 complete,  explore val = 0.01, episode reward = 36.0, ave reward = 47.6
# episode 207 of 1000 complete,  explore val = 0.01, episode reward = 35.0, ave reward = 47.8
# episode 208 of 1000 complete,  explore val = 0.01, episode reward = 66.0, ave reward = 47.5
# episode 209 of 1000 complete,  explore val = 0.01, episode reward = 36.0, ave reward = 47.2
# episode 210 of 1000 complete,  explore val = 0.01, episode reward = 29.0, ave reward = 46.8
# episode 211 of 1000 complete,  explore val = 0.01, episode reward = 23.0, ave reward = 46.7
# episode 212 of 1000 complete,  explore val = 0.01, episode reward = 69.0, ave reward = 47.2
# episode 213 of 1000 complete,  explore val = 0.01, episode reward = 104.0, ave reward = 48.0
# episode 214 of 1000 complete,  explore val = 0.01, episode reward = 53.0, ave reward = 48.3
# episode 215 of 1000 complete,  explore val = 0.01, episode reward = 204.0, ave reward = 50.2
# episode 216 of 1000 complete,  explore val = 0.01, episode reward = 76.0, ave reward = 50.2
# episode 217 of 1000 complete,  explore val = 0.01, episode reward = 48.0, ave reward = 50.5
# episode 218 of 1000 complete,  explore val = 0.01, episode reward = 33.0, ave reward = 50.7
# episode 219 of 1000 complete,  explore val = 0.01, episode reward = 20.0, ave reward = 50.7
# episode 220 of 1000 complete,  explore val = 0.01, episode reward = 27.0, ave reward = 50.5
# episode 221 of 1000 complete,  explore val = 0.01, episode reward = 72.0, ave reward = 50.5
# episode 222 of 1000 complete,  explore val = 0.01, episode reward = 63.0, ave reward = 50.4
# episode 223 of 1000 complete,  explore val = 0.01, episode reward = 31.0, ave reward = 50.5
# episode 224 of 1000 complete,  explore val = 0.01, episode reward = 33.0, ave reward = 50.6
# episode 225 of 1000 complete,  explore val = 0.01, episode reward = 97.0, ave reward = 51.1
# episode 226 of 1000 complete,  explore val = 0.01, episode reward = 202.0, ave reward = 52.5
# episode 227 of 1000 complete,  explore val = 0.01, episode reward = 54.0, ave reward = 52.8
# episode 228 of 1000 complete,  explore val = 0.01, episode reward = 39.0, ave reward = 52.7
# episode 229 of 1000 complete,  explore val = 0.01, episode reward = 37.0, ave reward = 52.3
# episode 230 of 1000 complete,  explore val = 0.01, episode reward = 41.0, ave reward = 51.8
# episode 231 of 1000 complete,  explore val = 0.01, episode reward = 179.0, ave reward = 53.3
# episode 232 of 1000 complete,  explore val = 0.01, episode reward = 38.0, ave reward = 53.5
# episode 233 of 1000 complete,  explore val = 0.01, episode reward = 43.0, ave reward = 53.7
# episode 234 of 1000 complete,  explore val = 0.01, episode reward = 54.0, ave reward = 54.0
# episode 235 of 1000 complete,  explore val = 0.01, episode reward = 43.0, ave reward = 54.1
# episode 236 of 1000 complete,  explore val = 0.01, episode reward = 74.0, ave reward = 54.4
# episode 237 of 1000 complete,  explore val = 0.01, episode reward = 54.0, ave reward = 54.8
# episode 238 of 1000 complete,  explore val = 0.01, episode reward = 40.0, ave reward = 54.2
# episode 239 of 1000 complete,  explore val = 0.01, episode reward = 37.0, ave reward = 54.4
# episode 240 of 1000 complete,  explore val = 0.01, episode reward = 58.0, ave reward = 54.4
# episode 241 of 1000 complete,  explore val = 0.01, episode reward = 51.0, ave reward = 54.2
# episode 242 of 1000 complete,  explore val = 0.01, episode reward = 39.0, ave reward = 54.4
# episode 243 of 1000 complete,  explore val = 0.01, episode reward = 66.0, ave reward = 55.0
# episode 244 of 1000 complete,  explore val = 0.01, episode reward = 82.0, ave reward = 55.6
# episode 245 of 1000 complete,  explore val = 0.01, episode reward = 67.0, ave reward = 55.9
# episode 246 of 1000 complete,  explore val = 0.01, episode reward = 25.0, ave reward = 55.7
# episode 247 of 1000 complete,  explore val = 0.01, episode reward = 30.0, ave reward = 55.8
# episode 248 of 1000 complete,  explore val = 0.01, episode reward = 23.0, ave reward = 55.4
# episode 249 of 1000 complete,  explore val = 0.01, episode reward = 51.0, ave reward = 54.8
# episode 250 of 1000 complete,  explore val = 0.01, episode reward = 40.0, ave reward = 54.7
# episode 251 of 1000 complete,  explore val = 0.01, episode reward = 42.0, ave reward = 54.7
# episode 252 of 1000 complete,  explore val = 0.01, episode reward = 221.0, ave reward = 56.6
# episode 253 of 1000 complete,  explore val = 0.01, episode reward = 58.0, ave reward = 56.9
# episode 254 of 1000 complete,  explore val = 0.01, episode reward = 230.0, ave reward = 59.0
# episode 255 of 1000 complete,  explore val = 0.01, episode reward = 310.0, ave reward = 61.9
# episode 256 of 1000 complete,  explore val = 0.01, episode reward = 52.0, ave reward = 61.1
# episode 257 of 1000 complete,  explore val = 0.01, episode reward = 59.0, ave reward = 61.5
# episode 258 of 1000 complete,  explore val = 0.01, episode reward = 51.0, ave reward = 61.2
# episode 259 of 1000 complete,  explore val = 0.01, episode reward = 72.0, ave reward = 61.6
# episode 260 of 1000 complete,  explore val = 0.01, episode reward = 85.0, ave reward = 62.0
# episode 261 of 1000 complete,  explore val = 0.01, episode reward = 109.0, ave reward = 62.7
# episode 262 of 1000 complete,  explore val = 0.01, episode reward = 51.0, ave reward = 62.9
# episode 263 of 1000 complete,  explore val = 0.01, episode reward = 50.0, ave reward = 63.1
# episode 264 of 1000 complete,  explore val = 0.01, episode reward = 54.0, ave reward = 63.3
# episode 265 of 1000 complete,  explore val = 0.01, episode reward = 64.0, ave reward = 63.5
# episode 266 of 1000 complete,  explore val = 0.01, episode reward = 52.0, ave reward = 62.4
# episode 267 of 1000 complete,  explore val = 0.01, episode reward = 34.0, ave reward = 62.3
# episode 268 of 1000 complete,  explore val = 0.01, episode reward = 93.0, ave reward = 63.0
# episode 269 of 1000 complete,  explore val = 0.01, episode reward = 47.0, ave reward = 63.2
# episode 270 of 1000 complete,  explore val = 0.01, episode reward = 82.0, ave reward = 63.6
# episode 271 of 1000 complete,  explore val = 0.01, episode reward = 50.0, ave reward = 63.8
# episode 272 of 1000 complete,  explore val = 0.01, episode reward = 89.0, ave reward = 63.4
# episode 273 of 1000 complete,  explore val = 0.01, episode reward = 146.0, ave reward = 64.5
# episode 274 of 1000 complete,  explore val = 0.01, episode reward = 70.0, ave reward = 64.4
# episode 275 of 1000 complete,  explore val = 0.01, episode reward = 100.0, ave reward = 64.9
# episode 276 of 1000 complete,  explore val = 0.01, episode reward = 53.0, ave reward = 65.0
# episode 277 of 1000 complete,  explore val = 0.01, episode reward = 69.0, ave reward = 65.4
# episode 278 of 1000 complete,  explore val = 0.01, episode reward = 55.0, ave reward = 65.8
# episode 279 of 1000 complete,  explore val = 0.01, episode reward = 31.0, ave reward = 65.8
# episode 280 of 1000 complete,  explore val = 0.01, episode reward = 57.0, ave reward = 66.2
# episode 281 of 1000 complete,  explore val = 0.01, episode reward = 59.0, ave reward = 65.8
# episode 282 of 1000 complete,  explore val = 0.01, episode reward = 72.0, ave reward = 66.0
# episode 283 of 1000 complete,  explore val = 0.01, episode reward = 48.0, ave reward = 66.3
# episode 284 of 1000 complete,  explore val = 0.01, episode reward = 43.0, ave reward = 66.6
# episode 285 of 1000 complete,  explore val = 0.01, episode reward = 102.0, ave reward = 67.4
# episode 286 of 1000 complete,  explore val = 0.01, episode reward = 62.0, ave reward = 67.4
# episode 287 of 1000 complete,  explore val = 0.01, episode reward = 48.0, ave reward = 67.4
# episode 288 of 1000 complete,  explore val = 0.01, episode reward = 103.0, ave reward = 68.1
# episode 289 of 1000 complete,  explore val = 0.01, episode reward = 60.0, ave reward = 68.3
# episode 290 of 1000 complete,  explore val = 0.01, episode reward = 85.0, ave reward = 68.5
# episode 291 of 1000 complete,  explore val = 0.01, episode reward = 96.0, ave reward = 68.3
# episode 292 of 1000 complete,  explore val = 0.01, episode reward = 66.0, ave reward = 68.5
# episode 293 of 1000 complete,  explore val = 0.01, episode reward = 201.0, ave reward = 70.1
# episode 294 of 1000 complete,  explore val = 0.01, episode reward = 240.0, ave reward = 72.3
# episode 295 of 1000 complete,  explore val = 0.01, episode reward = 97.0, ave reward = 73.1
# episode 296 of 1000 complete,  explore val = 0.01, episode reward = 80.0, ave reward = 73.3
# episode 297 of 1000 complete,  explore val = 0.01, episode reward = 77.0, ave reward = 73.7
# episode 298 of 1000 complete,  explore val = 0.01, episode reward = 33.0, ave reward = 73.8
# episode 299 of 1000 complete,  explore val = 0.01, episode reward = 50.0, ave reward = 73.7
# episode 300 of 1000 complete,  explore val = 0.01, episode reward = 117.0, ave reward = 74.6
# episode 301 of 1000 complete,  explore val = 0.01, episode reward = 82.0, ave reward = 71.3
# episode 302 of 1000 complete,  explore val = 0.01, episode reward = 60.0, ave reward = 71.3
# episode 303 of 1000 complete,  explore val = 0.01, episode reward = 310.0, ave reward = 74.3
# episode 304 of 1000 complete,  explore val = 0.01, episode reward = 54.0, ave reward = 74.6
# episode 305 of 1000 complete,  explore val = 0.01, episode reward = 75.0, ave reward = 74.8
# episode 306 of 1000 complete,  explore val = 0.01, episode reward = 48.0, ave reward = 74.9
# episode 307 of 1000 complete,  explore val = 0.01, episode reward = 38.0, ave reward = 74.9
# episode 308 of 1000 complete,  explore val = 0.01, episode reward = 59.0, ave reward = 74.9
# episode 309 of 1000 complete,  explore val = 0.01, episode reward = 425.0, ave reward = 78.8
# episode 310 of 1000 complete,  explore val = 0.01, episode reward = 132.0, ave reward = 79.8
# episode 311 of 1000 complete,  explore val = 0.01, episode reward = 51.0, ave reward = 80.1
# episode 312 of 1000 complete,  explore val = 0.01, episode reward = 43.0, ave reward = 79.8
# episode 313 of 1000 complete,  explore val = 0.01, episode reward = 47.0, ave reward = 79.2
# episode 314 of 1000 complete,  explore val = 0.01, episode reward = 76.0, ave reward = 79.5
# episode 315 of 1000 complete,  explore val = 0.01, episode reward = 90.0, ave reward = 78.3
# episode 316 of 1000 complete,  explore val = 0.01, episode reward = 64.0, ave reward = 78.2
# episode 317 of 1000 complete,  explore val = 0.01, episode reward = 265.0, ave reward = 80.4
# episode 318 of 1000 complete,  explore val = 0.01, episode reward = 70.0, ave reward = 80.7
# episode 319 of 1000 complete,  explore val = 0.01, episode reward = 75.0, ave reward = 81.3
# episode 320 of 1000 complete,  explore val = 0.01, episode reward = 75.0, ave reward = 81.8
# episode 321 of 1000 complete,  explore val = 0.01, episode reward = 62.0, ave reward = 81.7
# episode 322 of 1000 complete,  explore val = 0.01, episode reward = 86.0, ave reward = 81.9
# episode 323 of 1000 complete,  explore val = 0.01, episode reward = 110.0, ave reward = 82.7
# episode 324 of 1000 complete,  explore val = 0.01, episode reward = 35.0, ave reward = 82.7
# episode 325 of 1000 complete,  explore val = 0.01, episode reward = 82.0, ave reward = 82.6
# episode 326 of 1000 complete,  explore val = 0.01, episode reward = 37.0, ave reward = 80.9
# episode 327 of 1000 complete,  explore val = 0.01, episode reward = 60.0, ave reward = 81.0
# episode 328 of 1000 complete,  explore val = 0.01, episode reward = 67.0, ave reward = 81.2
# episode 329 of 1000 complete,  explore val = 0.01, episode reward = 247.0, ave reward = 83.4
# episode 330 of 1000 complete,  explore val = 0.01, episode reward = 54.0, ave reward = 83.5
# episode 331 of 1000 complete,  explore val = 0.01, episode reward = 75.0, ave reward = 82.4
# episode 332 of 1000 complete,  explore val = 0.01, episode reward = 49.0, ave reward = 82.6
# episode 333 of 1000 complete,  explore val = 0.01, episode reward = 96.0, ave reward = 83.1
# episode 334 of 1000 complete,  explore val = 0.01, episode reward = 56.0, ave reward = 83.1
# episode 335 of 1000 complete,  explore val = 0.01, episode reward = 33.0, ave reward = 83.0
# episode 336 of 1000 complete,  explore val = 0.01, episode reward = 45.0, ave reward = 82.7
# episode 337 of 1000 complete,  explore val = 0.01, episode reward = 31.0, ave reward = 82.5
# episode 338 of 1000 complete,  explore val = 0.01, episode reward = 62.0, ave reward = 82.7
# episode 339 of 1000 complete,  explore val = 0.01, episode reward = 86.0, ave reward = 83.2
# episode 340 of 1000 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 87.6
# episode 341 of 1000 complete,  explore val = 0.01, episode reward = 302.0, ave reward = 90.1
# episode 342 of 1000 complete,  explore val = 0.01, episode reward = 277.0, ave reward = 92.5
# episode 343 of 1000 complete,  explore val = 0.01, episode reward = 78.0, ave reward = 92.6
# episode 344 of 1000 complete,  explore val = 0.01, episode reward = 48.0, ave reward = 92.3
# episode 345 of 1000 complete,  explore val = 0.01, episode reward = 55.0, ave reward = 92.2
# episode 346 of 1000 complete,  explore val = 0.01, episode reward = 74.0, ave reward = 92.6
# episode 347 of 1000 complete,  explore val = 0.01, episode reward = 60.0, ave reward = 93.0
# episode 348 of 1000 complete,  explore val = 0.01, episode reward = 132.0, ave reward = 94.0
# episode 349 of 1000 complete,  explore val = 0.01, episode reward = 176.0, ave reward = 95.3
# episode 350 of 1000 complete,  explore val = 0.01, episode reward = 240.0, ave reward = 97.3
# episode 351 of 1000 complete,  explore val = 0.01, episode reward = 93.0, ave reward = 97.8
# episode 352 of 1000 complete,  explore val = 0.01, episode reward = 49.0, ave reward = 96.1
# episode 353 of 1000 complete,  explore val = 0.01, episode reward = 70.0, ave reward = 96.2
# episode 354 of 1000 complete,  explore val = 0.01, episode reward = 79.0, ave reward = 94.7
# episode 355 of 1000 complete,  explore val = 0.01, episode reward = 211.0, ave reward = 93.7
# episode 356 of 1000 complete,  explore val = 0.01, episode reward = 78.0, ave reward = 94.0
# episode 357 of 1000 complete,  explore val = 0.01, episode reward = 79.0, ave reward = 94.2
# episode 358 of 1000 complete,  explore val = 0.01, episode reward = 85.0, ave reward = 94.5
# episode 359 of 1000 complete,  explore val = 0.01, episode reward = 97.0, ave reward = 94.8
# episode 360 of 1000 complete,  explore val = 0.01, episode reward = 115.0, ave reward = 95.0
# episode 361 of 1000 complete,  explore val = 0.01, episode reward = 52.0, ave reward = 94.5
# episode 362 of 1000 complete,  explore val = 0.01, episode reward = 58.0, ave reward = 94.6
# episode 363 of 1000 complete,  explore val = 0.01, episode reward = 159.0, ave reward = 95.6
# episode 364 of 1000 complete,  explore val = 0.01, episode reward = 64.0, ave reward = 95.7
# episode 365 of 1000 complete,  explore val = 0.01, episode reward = 117.0, ave reward = 96.3
# episode 366 of 1000 complete,  explore val = 0.01, episode reward = 88.0, ave reward = 96.6
# episode 367 of 1000 complete,  explore val = 0.01, episode reward = 178.0, ave reward = 98.1
# episode 368 of 1000 complete,  explore val = 0.01, episode reward = 124.0, ave reward = 98.4
# episode 369 of 1000 complete,  explore val = 0.01, episode reward = 87.0, ave reward = 98.8
# episode 370 of 1000 complete,  explore val = 0.01, episode reward = 108.0, ave reward = 99.0
# episode 371 of 1000 complete,  explore val = 0.01, episode reward = 55.0, ave reward = 99.1
# episode 372 of 1000 complete,  explore val = 0.01, episode reward = 72.0, ave reward = 98.9
# episode 373 of 1000 complete,  explore val = 0.01, episode reward = 162.0, ave reward = 99.1
# episode 374 of 1000 complete,  explore val = 0.01, episode reward = 367.0, ave reward = 102.0
# episode 375 of 1000 complete,  explore val = 0.01, episode reward = 285.0, ave reward = 103.9
# episode 376 of 1000 complete,  explore val = 0.01, episode reward = 297.0, ave reward = 106.3
# episode 377 of 1000 complete,  explore val = 0.01, episode reward = 211.0, ave reward = 107.8
# episode 378 of 1000 complete,  explore val = 0.01, episode reward = 102.0, ave reward = 108.2
# episode 379 of 1000 complete,  explore val = 0.01, episode reward = 79.0, ave reward = 108.7
# episode 380 of 1000 complete,  explore val = 0.01, episode reward = 102.0, ave reward = 109.2
# episode 381 of 1000 complete,  explore val = 0.01, episode reward = 310.0, ave reward = 111.7
# episode 382 of 1000 complete,  explore val = 0.01, episode reward = 91.0, ave reward = 111.9
# episode 383 of 1000 complete,  explore val = 0.01, episode reward = 208.0, ave reward = 113.5
# episode 384 of 1000 complete,  explore val = 0.01, episode reward = 290.0, ave reward = 115.9
# episode 385 of 1000 complete,  explore val = 0.01, episode reward = 52.0, ave reward = 115.4
# episode 386 of 1000 complete,  explore val = 0.01, episode reward = 178.0, ave reward = 116.6
# episode 387 of 1000 complete,  explore val = 0.01, episode reward = 145.0, ave reward = 117.6
# episode 388 of 1000 complete,  explore val = 0.01, episode reward = 104.0, ave reward = 117.6
# episode 389 of 1000 complete,  explore val = 0.01, episode reward = 57.0, ave reward = 117.5
# episode 390 of 1000 complete,  explore val = 0.01, episode reward = 54.0, ave reward = 117.2
# episode 391 of 1000 complete,  explore val = 0.01, episode reward = 53.0, ave reward = 116.8
# episode 392 of 1000 complete,  explore val = 0.01, episode reward = 57.0, ave reward = 116.7
# episode 393 of 1000 complete,  explore val = 0.01, episode reward = 396.0, ave reward = 118.7
# episode 394 of 1000 complete,  explore val = 0.01, episode reward = 134.0, ave reward = 117.6
# episode 395 of 1000 complete,  explore val = 0.01, episode reward = 105.0, ave reward = 117.7
# episode 396 of 1000 complete,  explore val = 0.01, episode reward = 79.0, ave reward = 117.7
# episode 397 of 1000 complete,  explore val = 0.01, episode reward = 72.0, ave reward = 117.6
# episode 398 of 1000 complete,  explore val = 0.01, episode reward = 47.0, ave reward = 117.8
# episode 399 of 1000 complete,  explore val = 0.01, episode reward = 91.0, ave reward = 118.2
# episode 400 of 1000 complete,  explore val = 0.01, episode reward = 348.0, ave reward = 120.5
# episode 401 of 1000 complete,  explore val = 0.01, episode reward = 205.0, ave reward = 121.7
# episode 402 of 1000 complete,  explore val = 0.01, episode reward = 42.0, ave reward = 121.5
# episode 403 of 1000 complete,  explore val = 0.01, episode reward = 44.0, ave reward = 118.9
# episode 404 of 1000 complete,  explore val = 0.01, episode reward = 119.0, ave reward = 119.5
# episode 405 of 1000 complete,  explore val = 0.01, episode reward = 166.0, ave reward = 120.4
# episode 406 of 1000 complete,  explore val = 0.01, episode reward = 110.0, ave reward = 121.0
# episode 407 of 1000 complete,  explore val = 0.01, episode reward = 69.0, ave reward = 121.4
# episode 408 of 1000 complete,  explore val = 0.01, episode reward = 136.0, ave reward = 122.1
# episode 409 of 1000 complete,  explore val = 0.01, episode reward = 60.0, ave reward = 118.5
# episode 410 of 1000 complete,  explore val = 0.01, episode reward = 122.0, ave reward = 118.4
# episode 411 of 1000 complete,  explore val = 0.01, episode reward = 94.0, ave reward = 118.8
# episode 412 of 1000 complete,  explore val = 0.01, episode reward = 61.0, ave reward = 119.0
# episode 413 of 1000 complete,  explore val = 0.01, episode reward = 37.0, ave reward = 118.9
# episode 414 of 1000 complete,  explore val = 0.01, episode reward = 35.0, ave reward = 118.5
# episode 415 of 1000 complete,  explore val = 0.01, episode reward = 30.0, ave reward = 117.9
# episode 416 of 1000 complete,  explore val = 0.01, episode reward = 31.0, ave reward = 117.6
# episode 417 of 1000 complete,  explore val = 0.01, episode reward = 135.0, ave reward = 116.2
# episode 418 of 1000 complete,  explore val = 0.01, episode reward = 77.0, ave reward = 116.3
# episode 419 of 1000 complete,  explore val = 0.01, episode reward = 95.0, ave reward = 116.5
# episode 420 of 1000 complete,  explore val = 0.01, episode reward = 89.0, ave reward = 116.7
# episode 421 of 1000 complete,  explore val = 0.01, episode reward = 88.0, ave reward = 116.9
# episode 422 of 1000 complete,  explore val = 0.01, episode reward = 81.0, ave reward = 116.9
# episode 423 of 1000 complete,  explore val = 0.01, episode reward = 65.0, ave reward = 116.4
# episode 424 of 1000 complete,  explore val = 0.01, episode reward = 67.0, ave reward = 116.7
# episode 425 of 1000 complete,  explore val = 0.01, episode reward = 90.0, ave reward = 116.8
# episode 426 of 1000 complete,  explore val = 0.01, episode reward = 66.0, ave reward = 117.1
# episode 427 of 1000 complete,  explore val = 0.01, episode reward = 64.0, ave reward = 117.2
# episode 428 of 1000 complete,  explore val = 0.01, episode reward = 53.0, ave reward = 117.0
# episode 429 of 1000 complete,  explore val = 0.01, episode reward = 85.0, ave reward = 115.4
# episode 430 of 1000 complete,  explore val = 0.01, episode reward = 30.0, ave reward = 115.2
# episode 431 of 1000 complete,  explore val = 0.01, episode reward = 34.0, ave reward = 114.7
# episode 432 of 1000 complete,  explore val = 0.01, episode reward = 40.0, ave reward = 114.6
# episode 433 of 1000 complete,  explore val = 0.01, episode reward = 96.0, ave reward = 114.6
# episode 434 of 1000 complete,  explore val = 0.01, episode reward = 76.0, ave reward = 114.8
# episode 435 of 1000 complete,  explore val = 0.01, episode reward = 82.0, ave reward = 115.3
# episode 436 of 1000 complete,  explore val = 0.01, episode reward = 71.0, ave reward = 115.6
# episode 437 of 1000 complete,  explore val = 0.01, episode reward = 85.0, ave reward = 116.1
# episode 438 of 1000 complete,  explore val = 0.01, episode reward = 83.0, ave reward = 116.4
# episode 439 of 1000 complete,  explore val = 0.01, episode reward = 51.0, ave reward = 116.0
# episode 440 of 1000 complete,  explore val = 0.01, episode reward = 41.0, ave reward = 111.4
# episode 441 of 1000 complete,  explore val = 0.01, episode reward = 154.0, ave reward = 109.9
# episode 442 of 1000 complete,  explore val = 0.01, episode reward = 37.0, ave reward = 107.5
# episode 443 of 1000 complete,  explore val = 0.01, episode reward = 58.0, ave reward = 107.3
# episode 444 of 1000 complete,  explore val = 0.01, episode reward = 110.0, ave reward = 108.0
# episode 445 of 1000 complete,  explore val = 0.01, episode reward = 41.0, ave reward = 107.8
# episode 446 of 1000 complete,  explore val = 0.01, episode reward = 218.0, ave reward = 109.2
# episode 447 of 1000 complete,  explore val = 0.01, episode reward = 67.0, ave reward = 109.3
# episode 448 of 1000 complete,  explore val = 0.01, episode reward = 113.0, ave reward = 109.1
# episode 449 of 1000 complete,  explore val = 0.01, episode reward = 77.0, ave reward = 108.1
# episode 450 of 1000 complete,  explore val = 0.01, episode reward = 82.0, ave reward = 106.6
# episode 451 of 1000 complete,  explore val = 0.01, episode reward = 152.0, ave reward = 107.2
# episode 452 of 1000 complete,  explore val = 0.01, episode reward = 158.0, ave reward = 108.2
# episode 453 of 1000 complete,  explore val = 0.01, episode reward = 359.0, ave reward = 111.1
# episode 454 of 1000 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 115.3
# episode 455 of 1000 complete,  explore val = 0.01, episode reward = 161.0, ave reward = 114.8
# episode 456 of 1000 complete,  explore val = 0.01, episode reward = 496.0, ave reward = 119.0
# episode 457 of 1000 complete,  explore val = 0.01, episode reward = 73.0, ave reward = 119.0
# episode 458 of 1000 complete,  explore val = 0.01, episode reward = 94.0, ave reward = 119.0
# episode 459 of 1000 complete,  explore val = 0.01, episode reward = 255.0, ave reward = 120.6
# episode 460 of 1000 complete,  explore val = 0.01, episode reward = 475.0, ave reward = 124.2
# episode 461 of 1000 complete,  explore val = 0.01, episode reward = 350.0, ave reward = 127.2
# episode 462 of 1000 complete,  explore val = 0.01, episode reward = 360.0, ave reward = 130.2
# episode 463 of 1000 complete,  explore val = 0.01, episode reward = 379.0, ave reward = 132.4
# episode 464 of 1000 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 136.8
# episode 465 of 1000 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 140.6
# episode 466 of 1000 complete,  explore val = 0.01, episode reward = 106.0, ave reward = 140.8
# episode 467 of 1000 complete,  explore val = 0.01, episode reward = 363.0, ave reward = 142.6
# episode 468 of 1000 complete,  explore val = 0.01, episode reward = 93.0, ave reward = 142.3
# episode 469 of 1000 complete,  explore val = 0.01, episode reward = 59.0, ave reward = 142.1
# episode 470 of 1000 complete,  explore val = 0.01, episode reward = 217.0, ave reward = 143.2
# episode 471 of 1000 complete,  explore val = 0.01, episode reward = 183.0, ave reward = 144.4
# episode 472 of 1000 complete,  explore val = 0.01, episode reward = 101.0, ave reward = 144.7
# episode 473 of 1000 complete,  explore val = 0.01, episode reward = 50.0, ave reward = 143.6
# episode 474 of 1000 complete,  explore val = 0.01, episode reward = 59.0, ave reward = 140.5
# episode 475 of 1000 complete,  explore val = 0.01, episode reward = 74.0, ave reward = 138.4
# episode 476 of 1000 complete,  explore val = 0.01, episode reward = 83.0, ave reward = 136.3
# episode 477 of 1000 complete,  explore val = 0.01, episode reward = 43.0, ave reward = 134.6
# episode 478 of 1000 complete,  explore val = 0.01, episode reward = 29.0, ave reward = 133.9
# episode 479 of 1000 complete,  explore val = 0.01, episode reward = 60.0, ave reward = 133.7
# episode 480 of 1000 complete,  explore val = 0.01, episode reward = 39.0, ave reward = 133.0
# episode 481 of 1000 complete,  explore val = 0.01, episode reward = 34.0, ave reward = 130.3
# episode 482 of 1000 complete,  explore val = 0.01, episode reward = 41.0, ave reward = 129.8
# episode 483 of 1000 complete,  explore val = 0.01, episode reward = 62.0, ave reward = 128.3
# episode 484 of 1000 complete,  explore val = 0.01, episode reward = 171.0, ave reward = 127.1
# episode 485 of 1000 complete,  explore val = 0.01, episode reward = 149.0, ave reward = 128.1
# episode 486 of 1000 complete,  explore val = 0.01, episode reward = 148.0, ave reward = 127.8
# episode 487 of 1000 complete,  explore val = 0.01, episode reward = 357.0, ave reward = 129.9
# episode 488 of 1000 complete,  explore val = 0.01, episode reward = 70.0, ave reward = 129.6
# episode 489 of 1000 complete,  explore val = 0.01, episode reward = 68.0, ave reward = 129.7
# episode 490 of 1000 complete,  explore val = 0.01, episode reward = 62.0, ave reward = 129.8
# episode 491 of 1000 complete,  explore val = 0.01, episode reward = 68.0, ave reward = 129.9
# episode 492 of 1000 complete,  explore val = 0.01, episode reward = 59.0, ave reward = 129.9
# episode 493 of 1000 complete,  explore val = 0.01, episode reward = 66.0, ave reward = 126.6
# episode 494 of 1000 complete,  explore val = 0.01, episode reward = 83.0, ave reward = 126.1
# episode 495 of 1000 complete,  explore val = 0.01, episode reward = 60.0, ave reward = 125.7
# episode 496 of 1000 complete,  explore val = 0.01, episode reward = 44.0, ave reward = 125.3
# episode 497 of 1000 complete,  explore val = 0.01, episode reward = 84.0, ave reward = 125.4
# episode 498 of 1000 complete,  explore val = 0.01, episode reward = 49.0, ave reward = 125.5
# episode 499 of 1000 complete,  explore val = 0.01, episode reward = 53.0, ave reward = 125.1
# episode 500 of 1000 complete,  explore val = 0.01, episode reward = 49.0, ave reward = 122.1
# episode 501 of 1000 complete,  explore val = 0.01, episode reward = 35.0, ave reward = 120.4
# episode 502 of 1000 complete,  explore val = 0.01, episode reward = 44.0, ave reward = 120.4
# episode 503 of 1000 complete,  explore val = 0.01, episode reward = 80.0, ave reward = 120.8
# episode 504 of 1000 complete,  explore val = 0.01, episode reward = 53.0, ave reward = 120.1
# episode 505 of 1000 complete,  explore val = 0.01, episode reward = 33.0, ave reward = 118.8
# episode 506 of 1000 complete,  explore val = 0.01, episode reward = 69.0, ave reward = 118.4
# episode 507 of 1000 complete,  explore val = 0.01, episode reward = 150.0, ave reward = 119.2
# episode 508 of 1000 complete,  explore val = 0.01, episode reward = 88.0, ave reward = 118.7
# episode 509 of 1000 complete,  explore val = 0.01, episode reward = 318.0, ave reward = 121.3
# episode 510 of 1000 complete,  explore val = 0.01, episode reward = 72.0, ave reward = 120.8
# episode 511 of 1000 complete,  explore val = 0.01, episode reward = 92.0, ave reward = 120.8
# episode 512 of 1000 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 125.2
# episode 513 of 1000 complete,  explore val = 0.01, episode reward = 158.0, ave reward = 126.4
# episode 514 of 1000 complete,  explore val = 0.01, episode reward = 42.0, ave reward = 126.4
# episode 515 of 1000 complete,  explore val = 0.01, episode reward = 71.0, ave reward = 126.8
# episode 516 of 1000 complete,  explore val = 0.01, episode reward = 54.0, ave reward = 127.1
# episode 517 of 1000 complete,  explore val = 0.01, episode reward = 135.0, ave reward = 127.1
# episode 518 of 1000 complete,  explore val = 0.01, episode reward = 46.0, ave reward = 126.8
# episode 519 of 1000 complete,  explore val = 0.01, episode reward = 101.0, ave reward = 126.8
# episode 520 of 1000 complete,  explore val = 0.01, episode reward = 169.0, ave reward = 127.6
# episode 521 of 1000 complete,  explore val = 0.01, episode reward = 52.0, ave reward = 127.3
# episode 522 of 1000 complete,  explore val = 0.01, episode reward = 100.0, ave reward = 127.5
# episode 523 of 1000 complete,  explore val = 0.01, episode reward = 93.0, ave reward = 127.7
# episode 524 of 1000 complete,  explore val = 0.01, episode reward = 283.0, ave reward = 129.9
# episode 525 of 1000 complete,  explore val = 0.01, episode reward = 59.0, ave reward = 129.6
# episode 526 of 1000 complete,  explore val = 0.01, episode reward = 423.0, ave reward = 133.2
# episode 527 of 1000 complete,  explore val = 0.01, episode reward = 130.0, ave reward = 133.8
# episode 528 of 1000 complete,  explore val = 0.01, episode reward = 204.0, ave reward = 135.3
# episode 529 of 1000 complete,  explore val = 0.01, episode reward = 348.0, ave reward = 138.0
# episode 530 of 1000 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 142.7
# episode 531 of 1000 complete,  explore val = 0.01, episode reward = 222.0, ave reward = 144.5
# episode 532 of 1000 complete,  explore val = 0.01, episode reward = 68.0, ave reward = 144.8
# episode 533 of 1000 complete,  explore val = 0.01, episode reward = 49.0, ave reward = 144.4
# episode 534 of 1000 complete,  explore val = 0.01, episode reward = 231.0, ave reward = 145.9
# episode 535 of 1000 complete,  explore val = 0.01, episode reward = 123.0, ave reward = 146.3
# episode 536 of 1000 complete,  explore val = 0.01, episode reward = 56.0, ave reward = 146.2
# episode 537 of 1000 complete,  explore val = 0.01, episode reward = 49.0, ave reward = 145.8
# episode 538 of 1000 complete,  explore val = 0.01, episode reward = 78.0, ave reward = 145.8
# episode 539 of 1000 complete,  explore val = 0.01, episode reward = 179.0, ave reward = 147.0
# episode 540 of 1000 complete,  explore val = 0.01, episode reward = 201.0, ave reward = 148.6
# episode 541 of 1000 complete,  explore val = 0.01, episode reward = 85.0, ave reward = 147.9
# episode 542 of 1000 complete,  explore val = 0.01, episode reward = 53.0, ave reward = 148.1
# episode 543 of 1000 complete,  explore val = 0.01, episode reward = 71.0, ave reward = 148.2
# episode 544 of 1000 complete,  explore val = 0.01, episode reward = 40.0, ave reward = 147.5
# episode 545 of 1000 complete,  explore val = 0.01, episode reward = 40.0, ave reward = 147.5
# episode 546 of 1000 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 150.3
# episode 547 of 1000 complete,  explore val = 0.01, episode reward = 37.0, ave reward = 150.0
# episode 548 of 1000 complete,  explore val = 0.01, episode reward = 85.0, ave reward = 149.8
# episode 549 of 1000 complete,  explore val = 0.01, episode reward = 197.0, ave reward = 151.0
# episode 550 of 1000 complete,  explore val = 0.01, episode reward = 201.0, ave reward = 152.2
# episode 551 of 1000 complete,  explore val = 0.01, episode reward = 450.0, ave reward = 155.1
# episode 552 of 1000 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 158.6
# episode 553 of 1000 complete,  explore val = 0.01, episode reward = 76.0, ave reward = 155.7
# episode 554 of 1000 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 155.7
# episode 555 of 1000 complete,  explore val = 0.01, episode reward = 448.0, ave reward = 158.6
# episode 556 of 1000 complete,  explore val = 0.01, episode reward = 79.0, ave reward = 154.4
# episode 557 of 1000 complete,  explore val = 0.01, episode reward = 315.0, ave reward = 156.8
# episode 558 of 1000 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 160.9
# episode 559 of 1000 complete,  explore val = 0.01, episode reward = 327.0, ave reward = 161.6
# episode 560 of 1000 complete,  explore val = 0.01, episode reward = 488.0, ave reward = 161.8
# episode 561 of 1000 complete,  explore val = 0.01, episode reward = 223.0, ave reward = 160.5
# episode 562 of 1000 complete,  explore val = 0.01, episode reward = 447.0, ave reward = 161.4
# episode 563 of 1000 complete,  explore val = 0.01, episode reward = 212.0, ave reward = 159.7
# episode 564 of 1000 complete,  explore val = 0.01, episode reward = 192.0, ave reward = 156.6
# episode 565 of 1000 complete,  explore val = 0.01, episode reward = 185.0, ave reward = 153.4
# episode 566 of 1000 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 157.4
# episode 567 of 1000 complete,  explore val = 0.01, episode reward = 418.0, ave reward = 157.9
# episode 568 of 1000 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 162.0
# episode 569 of 1000 complete,  explore val = 0.01, episode reward = 151.0, ave reward = 162.9
# episode 570 of 1000 complete,  explore val = 0.01, episode reward = 278.0, ave reward = 163.5
# episode 571 of 1000 complete,  explore val = 0.01, episode reward = 288.0, ave reward = 164.6
# episode 572 of 1000 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 168.6
# episode 573 of 1000 complete,  explore val = 0.01, episode reward = 459.0, ave reward = 172.7
# episode 574 of 1000 complete,  explore val = 0.01, episode reward = 205.0, ave reward = 174.1
# episode 575 of 1000 complete,  explore val = 0.01, episode reward = 222.0, ave reward = 175.6
# episode 576 of 1000 complete,  explore val = 0.01, episode reward = 380.0, ave reward = 178.6
# episode 577 of 1000 complete,  explore val = 0.01, episode reward = 186.0, ave reward = 180.0
# episode 578 of 1000 complete,  explore val = 0.01, episode reward = 390.0, ave reward = 183.6
# episode 579 of 1000 complete,  explore val = 0.01, episode reward = 162.0, ave reward = 184.6
# episode 580 of 1000 complete,  explore val = 0.01, episode reward = 204.0, ave reward = 186.3
# episode 581 of 1000 complete,  explore val = 0.01, episode reward = 188.0, ave reward = 187.8
# episode 582 of 1000 complete,  explore val = 0.01, episode reward = 128.0, ave reward = 188.7
# episode 583 of 1000 complete,  explore val = 0.01, episode reward = 174.0, ave reward = 189.8
# episode 584 of 1000 complete,  explore val = 0.01, episode reward = 225.0, ave reward = 190.4
# episode 585 of 1000 complete,  explore val = 0.01, episode reward = 290.0, ave reward = 191.8
# episode 586 of 1000 complete,  explore val = 0.01, episode reward = 241.0, ave reward = 192.7
# episode 587 of 1000 complete,  explore val = 0.01, episode reward = 189.0, ave reward = 191.0
# episode 588 of 1000 complete,  explore val = 0.01, episode reward = 193.0, ave reward = 192.2
# episode 589 of 1000 complete,  explore val = 0.01, episode reward = 158.0, ave reward = 193.2
# episode 590 of 1000 complete,  explore val = 0.01, episode reward = 253.0, ave reward = 195.1
# episode 591 of 1000 complete,  explore val = 0.01, episode reward = 166.0, ave reward = 196.0
# episode 592 of 1000 complete,  explore val = 0.01, episode reward = 216.0, ave reward = 197.6
# episode 593 of 1000 complete,  explore val = 0.01, episode reward = 240.0, ave reward = 199.4
# episode 594 of 1000 complete,  explore val = 0.01, episode reward = 222.0, ave reward = 200.7
# q-learning algorithm complete

# %% [markdown]
# # plot total episode reward history

# %%
reward_logname = 'reward_logs/' + savename + '.txt'
plotter.plot_reward_history(reward_logname,window_length = exit_window)
